# %%
from MTStrategy.EACommunicator_API import EACommunicator_API
from MTStrategy.Strategy.BbandKdBase import BbandKdBase
from MTStrategy.schedule import Strategy_Scheduler
import datetime as dt

mt = EACommunicator_API()
mt.Connect(server='localhost',port=5555)
mt.Get_instruments(False)

EU_shares = ['#ADS', '#AIR', '#AIRP', '#ALV', '#AXAF', '#BAS', '#BAYN', '#BEI',
             '#BMW', '#BNPP', '#BOUY', '#CBK', '#DAI', '#DANO', '#DB1', '#DBK', '#DPW', '#DTE',
             '#EON', '#FME', '#HRMS', '#IFX', '#LHA', '#LIN', '#LVMH', '#MICP', '#MUV2', '#OREP',
             '#RWE', '#SAP', '#SIE', '#TTEF', '#VOW']
Symbols=[]
for sid in mt.Symbols:
    if '#' in sid and '#ETF' not in sid and '#HK' not in sid and sid not in EU_shares:
        tick = mt.Get_last_tick_info(sid)
        #if tick['ask'] <= 100 and tick['ask'] > 50:
        Symbols.append(sid)



strategy = BbandKdBase(mt, Symbols)

scheduler = Strategy_Scheduler(strategy=strategy,
                               mt = mt,
                               trade_time_list= [
                                   dt.time(hour=9,minute=30,second=0),
                                   dt.time(hour=10,minute=30,second=0),
                                   dt.time(hour=11,minute=30,second=0),
                                   dt.time(hour=12,minute=30,second=0),
                                   dt.time(hour=13,minute=30,second=0),
                                   dt.time(hour=14,minute=30,second=0),
                                   dt.time(hour=15,minute=30,second=0),
                                   dt.time(hour=16,minute=0,second=0)],
                               idle_second = 0
                              )
# Out:
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AAL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AAPL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ABNB failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ABT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ADBE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ADS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AI failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AIG failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AIR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AIRP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AKAM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ALL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ALV failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AMC failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AMZN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ANF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ATHM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AXAF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #AXP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BABA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BAC failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BAS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BAYN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BB failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BBY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BEI failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BEN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BIDU failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BIIB failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BLK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BMW failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BMY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BNPP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BOUY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #BRKb failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #C failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CAT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CBK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CMCSA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CMG failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #COIN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #COMP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #COP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #COST failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #COUR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CPNG failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CRM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CSCO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CVS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #CVX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DAI failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DAL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DANO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DASH failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DB1 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DBK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DBX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DFS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DIS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DLTR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DOCS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DOCU failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DPW failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DTE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #DUK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #EBAY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #EON failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-ARGT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-ASHR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-EEM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-EFA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-EIDO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-EPU failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-EWT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-EWW failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-EWZ failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-EZA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-GDX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-GLD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-GXC failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-ILF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-KSA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-SMIN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-USO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-VNM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-VTI failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-VUG failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-XLE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-XLF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ETF-XLK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #F failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #FB failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #FDX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #FME failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #FSLY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #GDDY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #GE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #GILD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #GM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #GME failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #GOOG failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #GS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HAL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HAYW failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0001 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0002 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0005 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0011 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0012 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0016 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0017 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0019 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0066 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0168 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0175 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0241 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0291 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0293 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0322 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0388 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0392 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0489 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0656 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0688 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0700 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0763 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0772 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0813 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0868 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0881 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0914 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK0939 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1024 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1044 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1088 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1109 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1299 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1398 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1658 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1810 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1918 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK1929 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK2020 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK2318 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK2388 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK2628 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK3188 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK3328 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK3333 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK6862 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK9618 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK9633 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HK9988 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HLT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HOG failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HON failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HPQ failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #HRMS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #IBM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #IFX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ILMN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #INTC failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #JD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #JNJ failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #JPM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #KHC failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #KO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #L failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LHA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LI failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LIN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LLY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LMND failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LMT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LU failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LUV failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LVMH failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LVS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #LYFT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MAR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MCD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MCO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MET failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MGM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MICP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MMM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MRK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MRNA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MSFT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MSI failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #MUV2 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #NFLX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #NIO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #NKE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #NOK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #NRG failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #NTES failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #NVDA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #OLED failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #OLO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #OMC failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ORCL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #OREP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PATH failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PBR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PCOR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PDD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PEP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PFE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PG failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PINS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PNC failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PRU failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #PYPL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #QCOM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #RACE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #RBLX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #RWE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SAP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SBUX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SCHW failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SHAK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SHOP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SIE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SNAP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SNOW failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SONY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SQ failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #SQSP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #T failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TGT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TLRY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TME failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TMUS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TRIP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TSLA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TSM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TSN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TTEF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TUYA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #TWLO failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #U failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #UAL failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #UBER failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #UGI failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #UPS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #V failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #VALE failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #VIPS failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #VOW failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #VRSN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #VZ failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #W failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #WB failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #WBA failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #WFC failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #WMT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #WYNN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #XOM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #XPEV failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #YELP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of #ZM failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of ADAUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of AUDCAD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of AUDCHF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of AUDJPY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of AUDNZD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of AUDUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of AUS200 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of BCHUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of BNBUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of BRENT failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of BTCUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of CADCHF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of CADJPY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of CHFJPY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of CHI50 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of DOGUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of DOTUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of ESP35 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of ETHUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EU50 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURAUD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURCAD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURCHF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURGBP failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURHUF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURJPY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURNZD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURPLN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of EURUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of FRA40 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GBPAUD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GBPCAD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GBPCHF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GBPJPY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GBPNZD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GBPUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GER30 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GOLD_APR24 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of GOLD_JUN24 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of HG_MAY24 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of HK50 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of HKCH50 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of IT40 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of JP225 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of LNKUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of LTCUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of NAS100 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of NGAS.MAY24 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of NZDCAD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of NZDCHF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of NZDJPY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of NZDUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of SPX500 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of UK100 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of UKOIL.JUN24 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of UKOIL.MAY24 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of UNIUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of US2000 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of US30 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDCAD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDCHF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDCNH failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDCZK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDDKK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDHKD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDHUF failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDJPY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDMXN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDNOK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDPLN failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDSEK failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDSGD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDTRY failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDX failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDX_JUN24 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USDZAR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of USOIL.MAY24 failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of WTI failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of XAGUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of XAUEUR failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of XAUUSD failed ! Remove from symbol list.
# [EACommunicator_API:Get_instruments:ERROR] Retreive Tick of XLMUSD failed ! Remove from symbol list.
# [BbandKdBase:INFO] initialzation
# [BbandKdBase:INFO] symbol = ['#WDAY']
# [BbandKdBase:INFO] parameters
# entry.nbrofbars                     =                   30
# entry.bb_near_ratio                 =                 0.15
# entry.bb_window                     =                    5
# entry.rr_ratio                      =                  2.0
# entry.min_price                     =                   10
# open_trade.money                    =                10000
# open_trade.lotsize_limit            =                0.005
# open_trade.timeframe                =                    D
# open_trade.drop_vio_lotsize         =                    0
# exit.timeframe                      =                    D
# exit.nbrofbars                      =                   30
# exit.kd_window                      =                    5
# exit.bb_near_ratio                  =                 0.15
# close_trade.SL_mode                 =                    2
# close_trade.timeframe               =                    D
# close_trade.nbrofbars               =                   30

# %%
scheduler.start(end_date_mrk=dt.datetime.strptime('20240314','%Y%m%d'))
# Out:
# Strategy[BbandKdBase] Scheduled
# @LocalTime =2022-02-18T22:51:00+08:00
# @ServerTime=2022-02-18T16:51:00+02:00
# @MarketTime=2022-02-18T09:51:00-05:00
# exec_times = 1

# %%
import pytz
scheduler.start(end_date_mrk=dt.datetime.now().astimezone(pytz.timezone('America/New_York')).replace(hour=15,minute=0,second=0))
# Out:
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00
# Tick Finished @ServerTime 2024-03-22T23:54:59+02:00

# %%
scheduler.stop()

# %%
mt.Break()
# Out:
# ---------------------------------------------------------------------------
# ZMQError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mt.Break()
#
# File d:\Python\workspace\MT4_EA_LIB\MTStrategy\EACommunicator_API.py:649, in EACommunicator_API.Break(self)
#     646 def Break(self):
#     647
#     648     # print(f"Sending command: {msg}")
# --> 649     self.socket.send_string('break^')
#     651     # Receive the reply from the server
#     652     reply = self.socket.recv_string()
#
# File d:\Python\anaconda3\Lib\site-packages\zmq\sugar\socket.py:828, in Socket.send_string(self, u, flags, copy, encoding, **kwargs)
#     826 if not isinstance(u, str):
#     827     raise TypeError("str objects only")
# --> 828 return self.send(u.encode(encoding), flags=flags, copy=copy, **kwargs)
#
# File d:\Python\anaconda3\Lib\site-packages\zmq\sugar\socket.py:618, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     611         data = zmq.Frame(
#     612             data,
#     613             track=track,
#     614             copy=copy or None,
#     615             copy_threshold=self.copy_threshold,
#     616         )
#     617     data.group = group
# --> 618 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:740, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:787, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:249, in zmq.backend.cython.socket._send_copy()
#
# File zmq\backend\cython\socket.pyx:244, in zmq.backend.cython.socket._send_copy()
#
# File d:\Python\anaconda3\Lib\site-packages\zmq\backend\cython\checkrc.pxd:28, in zmq.backend.cython.checkrc._check_rc()
#
# ZMQError: Operation cannot be accomplished in current state

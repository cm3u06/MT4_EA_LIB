# %%
from EACommunicator_API import EACommunicator_API
import sys

############################################
# ALL API
############################################
#
#
#    def Disconnect(self):
#    def Connect(self,
#                server: str = 'localhost',
#                port: int = 5555) -> bool:
#    def Check_connection(self) -> bool:
#    def IsConnected(self) -> bool:
#    def Get_instrument_info(self,
#                            instrument: str = 'EURUSD') -> dict:
#    def Update_instruments(self, selected=True) -> bool:
#    def Get_instruments(self, selected=True) ->list:
#    def Get_last_x_ticks_from_now(self,
#                                  instrument: str = 'EURUSD',
#                                  nbrofticks: int = 2000) -> np.array:
#    def Get_last_x_bars_from_now(self,
#                                 instrument: str = 'EURUSD',
#                                 timeframe: str = 'D1',
#                                 nbrofbars: int = 1000) -> np.array:
#    def Get_all_orders(self) -> pd.DataFrame:
#    def readCsv(self, inputCsvString):
#    def Get_all_open_positions(self) -> pd.DataFrame:
#    def Get_all_closed_positions(self) -> pd.DataFrame:
#    def Open_order(self,
#                   instrument: str = '',
#                   ordertype: str = 'buy',
#                   volume: float = 0.01,
#                   openprice: float = 0.0,
#                   slippage: int = 5,
#                   magicnumber: int = 0,
#                   stoploss: float = 0.0,
#                   takeprofit: float = 0.0,
#                   comment: str = '',
#                   market: bool = False
#                   ) -> int:
#    def Close_position_by_ticket(self,
#                                 ticket: int = 0) -> bool:
#    def Close_position_partial_by_ticket(self,
#                                         ticket: int = 0,
#                                         volume_to_close: float = 0.01) -> bool:
#    def Delete_order_by_ticket(self,
#                               ticket: int = 0) -> bool:
#    def Set_sl_and_tp_for_position(self,
#                                   ticket: int = 0,
#                                   stoploss: float = 0.0,
#                                   takeprofit: float = 0.0) -> bool:
#    def Set_sl_and_tp_for_order(self,
#                                ticket: int = 0,
#                                stoploss: float = 0.0,
#                                takeprofit: float = 0.0) -> bool:
#    def Change_settings_for_pending_order(self,
#                                ticket: int = 0,
#                                price: float = -1.0,
#                                stoploss: float = -1.0,
#                                takeprofit: float = -1.0) -> bool:
#    def Get_last_tick_info(self, symbol):
#    def send_command(self,
#                     command: TradingCommands, arguments: str = ''):
#    def get_timeframe_value(self,
#                            timeframe: str = 'M1') -> int:

# %%
mt = EACommunicator_API()
mt.Connect(server='host.docker.internal')

# %%
Symbols = mt.Get_instruments(False)

# %%
stocks=[]
for sid in mt.Symbols:
    if '#' in sid and '#ETF' not in sid and '#HK' not in sid:
        tick = mt.Get_last_tick_info(sid)
        #if tick['ask'] <= 100 and tick['ask'] > 50:
        stocks.append(sid)
stocks
# Out:
# ['#AA',
#  '#AAL',
#  '#AAPL',
#  '#ABNB',
#  '#ABT',
#  '#ADBE',
#  '#ADS',
#  '#AI',
#  '#AIG',
#  '#AIR',
#  '#AIRP',
#  '#AKAM',
#  '#ALL',
#  '#ALV',
#  '#AMC',
#  '#AMZN',
#  '#ANF',
#  '#ATHM',
#  '#AXAF',
#  '#AXP',
#  '#BA',
#  '#BABA',
#  '#BAC',
#  '#BAS',
#  '#BAYN',
#  '#BB',
#  '#BBY',
#  '#BEI',
#  '#BEN',
#  '#BIDU',
#  '#BIIB',
#  '#BK',
#  '#BLK',
#  '#BMW',
#  '#BMY',
#  '#BNPP',
#  '#BOUY',
#  '#BRKb',
#  '#C',
#  '#CAT',
#  '#CBK',
#  '#CL',
#  '#CMCSA',
#  '#CMG',
#  '#COIN',
#  '#COMP',
#  '#COP',
#  '#COST',
#  '#COUR',
#  '#CPNG',
#  '#CRM',
#  '#CSCO',
#  '#CVS',
#  '#CVX',
#  '#DAI',
#  '#DAL',
#  '#DANO',
#  '#DASH',
#  '#DB1',
#  '#DBK',
#  '#DBX',
#  '#DFS',
#  '#DIS',
#  '#DLTR',
#  '#DOCS',
#  '#DOCU',
#  '#DPW',
#  '#DTE',
#  '#DUK',
#  '#EBAY',
#  '#EON',
#  '#F',
#  '#FB',
#  '#FDX',
#  '#FME',
#  '#FSLY',
#  '#GDDY',
#  '#GE',
#  '#GILD',
#  '#GM',
#  '#GME',
#  '#GOOG',
#  '#GS',
#  '#HAL',
#  '#HAYW',
#  '#HD',
#  '#HLT',
#  '#HOG',
#  '#HON',
#  '#HPQ',
#  '#HRMS',
#  '#IBM',
#  '#IFX',
#  '#ILMN',
#  '#INTC',
#  '#JD',
#  '#JNJ',
#  '#JPM',
#  '#KHC',
#  '#KO',
#  '#L',
#  '#LHA',
#  '#LI',
#  '#LIN',
#  '#LLY',
#  '#LMND',
#  '#LMT',
#  '#LU',
#  '#LUV',
#  '#LVMH',
#  '#LVS',
#  '#LYFT',
#  '#MA',
#  '#MAR',
#  '#MCD',
#  '#MCO',
#  '#MET',
#  '#MGM',
#  '#MICP',
#  '#MMM',
#  '#MO',
#  '#MRK',
#  '#MRNA',
#  '#MS',
#  '#MSFT',
#  '#MSI',
#  '#MUV2',
#  '#NFLX',
#  '#NIO',
#  '#NKE',
#  '#NOK',
#  '#NRG',
#  '#NTES',
#  '#NVDA',
#  '#OLED',
#  '#OLO',
#  '#OMC',
#  '#ORCL',
#  '#OREP',
#  '#PATH',
#  '#PBR',
#  '#PCOR',
#  '#PDD',
#  '#PEP',
#  '#PFE',
#  '#PG',
#  '#PINS',
#  '#PM',
#  '#PNC',
#  '#PRU',
#  '#PYPL',
#  '#QCOM',
#  '#RACE',
#  '#RBLX',
#  '#RWE',
#  '#SAP',
#  '#SBUX',
#  '#SCHW',
#  '#SHAK',
#  '#SHOP',
#  '#SIE',
#  '#SNAP',
#  '#SNOW',
#  '#SONY',
#  '#SQ',
#  '#SQSP',
#  '#T',
#  '#TGT',
#  '#TLRY',
#  '#TM',
#  '#TME',
#  '#TMUS',
#  '#TRIP',
#  '#TSLA',
#  '#TSM',
#  '#TSN',
#  '#TTEF',
#  '#TUYA',
#  '#TWLO',
#  '#U',
#  '#UAL',
#  '#UBER',
#  '#UGI',
#  '#UPS',
#  '#V',
#  '#VALE',
#  '#VIPS',
#  '#VOW',
#  '#VRSN',
#  '#VZ',
#  '#W',
#  '#WB',
#  '#WBA',
#  '#WDAY',
#  '#WFC',
#  '#WMT',
#  '#WYNN',
#  '#XOM',
#  '#XPEV',
#  '#YELP',
#  '#ZM']

# %%
#stocks = [
# '#AAPL','#ADBE', '#AMZN', '#BABA', '#COST', '#CPNG', '#EBAY', '#GOOG', '#IBM', '#INTC', '#JNJ', '#KO', 
# '#MMM', '#MO', '#MSFT',  '#NFLX', '#NKE',  '#NVDA',  '#PG',  '#QCOM',  '#SONY',  '#TSLA', '#TSM',  '#UBER',  '#WMT',  ]

#stocks = ['#AIG', '#BABA', '#BBY', '#BK', '#BMY', '#BNPP', '#C', '#CL', '#CVS', '#DAI',
# '#DANO', '#DOCU', '#DUK', '#GILD', '#KO', '#L', '#LVS', '#MET', '#MMM', '#MRNA',
# '#MS', '#NRG', '#OMC', '#PCOR', '#PM', '#PYPL', '#SBUX', '#SCHW', '#SHAK', '#SHOP',
# '#SONY', '#SQ', '#TSN', '#TTEF', '#TWLO', '#UBER', '#W', '#WFC', '#ZM']

stocks = ['#C']

# %% [markdown]
# ## Strategy : Stock Hit BBands LB

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 100)

def Get_ohlcv(instrument='EURUSD', timeframe='D', nbrofbars=20):
    df = pd.DataFrame(mt.Get_last_x_bars_from_now(instrument, timeframe,nbrofbars))
    df = df.iloc[:, 1:].set_index('Time')
    df.index = pd.to_datetime(df.index)
    df.columns = [c.lower() for c in df.columns]
    return df

# %%
from functools import reduce
def recursive_reduce(cond_dict, conditions):
    def reduce_op(a,b):
        if list(cond_dict.keys())[0]=='|':
            return a|b
        elif list(cond_dict.keys())[0]=='&':
            return a&b
        else:
            return False
    conds = []
    for cond in list(cond_dict.values())[0]:
        if type(cond) == dict:
            conds.append(recursive_reduce(cond, conditions))
        else:
            if cond in conditions.keys():
                conds.append(conditions[cond])
            else:
                print(cond + ' is not in conditions!')
            
    if list(cond_dict.keys())[0]=='~':
        return ~conds[0]
    else:
        return reduce(reduce_op, conds)

# %%
from talib import abstract
from functools import reduce
from tqdm import tqdm
import sys

def signal_gen_Strategy__STOCK_HIT_BBANDS_LB(stocks, 
                                             nbrofbars=20,
                                             kd_window=5,
                                             bb_window=5,
                                             bb_near_ratio=0.1,
                                             rr_ratio=1.8,
                                             min_price=10,
                                             debug=False):
    __fname__ = '[' + sys._getframe().f_code.co_name + ']'
    if debug:
        print(f'{__fname__}')

    signal = {}
    
    #for sid in stocks:
    for sid in tqdm(stocks):
        info = mt.Get_instrument_info(sid)
        tick = mt.Get_last_tick_info(sid)
        df = Get_ohlcv(instrument=sid, timeframe='D', nbrofbars=nbrofbars)
        KD = abstract.STOCH(df,fastk_period=9)
        BB = abstract.BBANDS(df, 21, 2.1, 2.1)
        

        def KD_bull_divergence(window=13,D_crs1_ub=20, D_crs2_lb=17,debug=False):
            # 2 crs up in window
            KD_diff = (KD['slowk']-KD['slowd'])
            KD_crs_up_pos = ((KD_diff > 0).astype(int).diff()>0)
            KD_crs_up_2 = KD_crs_up_pos.rolling(window).sum()>=2

            # crs up point bounding
            KD_crs_up_pos1 = (KD['slowd'] < D_crs1_ub) & KD_crs_up_pos
            KD_crs_up_pos2 = (KD['slowd'] > D_crs2_lb) & KD_crs_up_pos
            KD_crs_up_pos_order_id = pd.Series(np.nan, index=KD.index)
            KD_crs_up_pos_order_id[KD_crs_up_pos1] =  1
            KD_crs_up_pos_order_id[KD_crs_up_pos2] =  2
            KD_crs_up_pos_in_order = (KD_crs_up_pos_order_id.ffill() == 2) \
            & ((KD_crs_up_pos_order_id==1).rolling(window).sum() > 0) \
            & ((KD_crs_up_pos_order_id==2).rolling(window).sum() > 0)

            # crs up point D increase
            KD_crs_up_pos_d_inc = (KD['slowd'].where(KD_crs_up_pos1 | KD_crs_up_pos2).ffill())
            KD_crs_up_pos_d_inc_until = pd.Series(np.nan, index=KD.index)
            KD_crs_up_pos_d_inc_until[KD_crs_up_pos_d_inc.diff()>0] = True
            KD_crs_up_pos_d_inc_until = KD_crs_up_pos_d_inc_until.ffill()
            
            # crs up point low decrease 
            low_win5 = df['low'].rolling(5).min()
            KD_crs_up_pos_low_not_inc = (low_win5.where(KD_crs_up_pos1 | KD_crs_up_pos2).ffill())
            KD_crs_up_pos_low_not_inc_until = pd.Series(np.nan, index=KD.index)
            KD_crs_up_pos_low_not_inc_until[KD_crs_up_pos_low_not_inc.diff()<=0] = True
            KD_crs_up_pos_low_not_inc_until = KD_crs_up_pos_low_not_inc_until.ffill()

            if debug:
                print('KD_crs_up_pos')
                print(KD_crs_up_pos)
                print('KD_crs_up_2')
                print(KD_crs_up_2)
                print('KD_crs_up_pos1')
                print(KD_crs_up_pos1)
                print('KD_crs_up_pos2')
                print(KD_crs_up_pos2)
                print('KD_crs_up_pos_order_id')
                print(KD_crs_up_pos_order_id)
                print('KD_crs_up_pos_in_order')
                print(KD_crs_up_pos_in_order)
                print('KD_crs_up_pos_d_inc')
                print(KD_crs_up_pos_d_inc)
                print('KD_crs_up_pos_d_inc_until')
                print(KD_crs_up_pos_d_inc_until)
                print('KD_crs_up_pos_low_not_inc')
                print(KD_crs_up_pos_low_not_inc)
                print('KD_crs_up_pos_low_not_inc_until')
                print(KD_crs_up_pos_low_not_inc_until)

            return KD_crs_up_2 & KD_crs_up_pos_in_order & KD_crs_up_pos_d_inc_until & KD_crs_up_pos_low_not_inc_until
    
        conditions = {
            'KD_up_crs_D_lte20_win' : ( \
                (KD['slowk'] <= KD['slowd']).shift() \
                & (KD['slowk'] > KD['slowd']) \
                & (KD['slowd'] <= 20)
            ).rolling(kd_window).sum() > 0,
            'KD_diff_gte3' : KD['slowk'] - KD['slowd'] >= 3,
            'KD_diff_gte2' : KD['slowk'] - KD['slowd'] >= 2,
            'KD_diff_inc' : (KD['slowk']-KD['slowd']).diff() > 0,
            'KD_diff_inc_win2' : ((KD['slowk']-KD['slowd']).diff() > 0).rolling(2).sum() >= 2,
            'KD_K_slope_pos' : KD['slowk'] > KD['slowk'].shift(),
            'KD_D_slope_pos' : KD['slowd'] > KD['slowd'].shift(),
            'KD_K_slope_gte5' : (KD['slowk'] - KD['slowk'].shift()) >= 5,
            'KD_K_slope_gte10' : (KD['slowk'] - KD['slowk'].shift()) >= 10,
            'KD_bull_divergence' : KD_bull_divergence(window=13,D_crs1_ub=20, D_crs2_lb=17,debug=debug),
            'BB_nearLB_win' : ( \
                (df['low'] <= BB['lowerband']) \
                | ((df['low'] - BB['lowerband'])/(BB['middleband']-BB['lowerband']) <= bb_near_ratio ) \
            ).rolling(bb_window).sum() > 0,
            'BB_RiskReward' : ( ((BB['middleband']-tick['ask'])/ (tick['ask']-df['low'].rolling(5).min()+tick['spread']*info['point']) ) >= rr_ratio ),
            'BB_nearLB_win13' : ( \
                (df['low'] <= BB['lowerband']) \
                | ((df['low'] - BB['lowerband'])/(BB['middleband']-BB['lowerband']) <= bb_near_ratio ) \
            ).rolling(13).sum() > 0,
            'close_min' : (df['close'] > min_price),
            'close_gt_close1' : (df['close'] > df['close'].shift() ),
            'close_gt_high1' : (df['close'] > df['high'].shift() ),
            'close_gt_close_open_avg1' : (df['close'] > ((df['close']+df['open'])/2).shift() ),
            'up_candle1' : (df['close'] > df['open'] ).shift(),
        }

        cond_dict = \
        {'|' : [
            {'&' : [
                {'|': [
                    {'&':['KD_up_crs_D_lte20_win','KD_diff_gte3', 'KD_K_slope_gte5', 'KD_K_slope_pos', 'KD_diff_inc']},
                    'KD_bull_divergence'
                ]},
                'BB_RiskReward',
                'BB_nearLB_win',
                'close_min',
                {'|': [ {'&':['up_candle1','close_gt_close_open_avg1']}, 'close_gt_high1' ]}
            ]},
        ]}

        if debug:
            KD['diff'] = KD['slowk'] - KD['slowd']
            KD['diff>0'] = (KD['diff']>0).astype(int)
            KD['(diff>0).diff'] = KD['diff>0'].diff()
            KD['(diff>0).diff>0'] = (KD['(diff>0).diff']>0)
            print(f'price\n{df}')
            print(f'KD\n{KD}')
            print(f'BB\n{BB}')
            print(f'{__fname__}\n{conditions["BB_RiskReward"]}')
            #print(f'{__fname__}  RR_ratio = ({BB["middleband"].iloc[-1]}-{df["close"].iloc[-1]})/({df["close"].iloc[-1]}-{df["low"].iloc[-5:].min()}) = {(BB["middleband"].iloc[-1]-df["close"].iloc[-1])/(df["close"].iloc[-1]-df["low"].iloc[-5:].min())}')
            print(f'RR_ratio = ',
                  f'({BB["middleband"].iloc[-1]:.5f}-{tick["ask"]:.5f})/({tick["ask"]:.5f}-{df["low"].iloc[-5:].min()}+{tick["spread"]*info["point"]:.5f}) = ',
                  (BB["middleband"].iloc[-1]-tick["ask"])/(tick["ask"]-df["low"].iloc[-5:].min()+tick['spread']*info['point']))
            for k,v in conditions.items():
                print(f'{k} : {v.iloc[-1]}')
        
        signal[sid] = recursive_reduce(cond_dict, conditions)
        #signal[sid] =  reduce(lambda a,b:a&b, [conditions[c] for c in cond_sum[0]])]
    
    signal_df = pd.DataFrame(signal)

    return signal_df

# %%
from datetime import datetime


def open_trade_Strategy__STOCK_HIT_BBANDS_LB(
    stocks,
    money = 1000,
    timeframe='D',
    nbrofbars=10,
    lotsize_limit=0.005,
    debug=False):

    __fname__ = '[' + sys._getframe().f_code.co_name + ']'
    money_each_order = money * lotsize_limit
    
    ticket = {}
    for sid in stocks:
        df = Get_ohlcv(instrument=sid, timeframe=timeframe, nbrofbars=nbrofbars)
        print(f'{__fname__} {sid} ==============')
        info = mt.Get_instrument_info(sid)
        tick = mt.Get_last_tick_info(sid)
        ask = tick['ask']
        lowest = df['low'].iloc[-5:].min()
        risk = max(ask - lowest + info['point']*tick['spread'] , info['stop_level']*info['point'])
        stoploss = ask - risk
        #lotsize = max(money_each_order / risk //info['lot_step'] *info['lot_step'] , info['min_lotsize'])
        lotsize = money_each_order / risk //info['lot_step'] *info['lot_step']
        if debug:
            print(f'{__fname__} info = {info}')
            print(f'{__fname__} tick = {tick}')
            print(f'{__fname__} ask = {ask}, lowest = {lowest}')
        print(f'{__fname__} lotsize = {lotsize:.2f}, openprice = {ask}, stoploss = {stoploss}')
        if lotsize_limit is None or lotsize >= info['min_lotsize']:
            ticket[sid] =  mt.Open_order(
                instrument = sid,
                ordertype = 'buy',
                volume = lotsize,
                openprice = ask,
                slippage = 3,
                stoploss= stoploss,
                takeprofit= 0,
                comment = 'STOCK_HIT_BBANDS_LB' )
        else:
            print(f'lotsize is too small to open trade !')
            
        print(f'=================================')
        print()

# %%
from datetime import datetime


def close_trade_Strategy__STOCK_HIT_BBANDS_UB(
    timeframe='D',
    nbrofbars=30,
    kd_window=5,
    bb_window=5,
    bb_near_ratio=0.1,
    TrackStopLoss=True,
    debug=False):

    __fname__ = '[' + sys._getframe().f_code.co_name + ']'
    print(f'{__fname__}')
    open_position = mt.Get_all_open_positions()

    for sid in open_position['symbol'].drop_duplicates():
        df = Get_ohlcv(instrument=sid, timeframe=timeframe, nbrofbars=nbrofbars)
        KD = abstract.STOCH(df,fastk_period=9)
        BB = abstract.BBANDS(df, 21, 2.1, 2.1)
        
    
        conditions = {
           'KD' : ( \
               (KD['slowk'] >= KD['slowd']).shift() \
             & (KD['slowk'] < KD['slowd']) \
             & (KD['slowd'] >= 80) \
           ).rolling(kd_window).sum()>0,
           'BB_NearUB' :  ( \
               (BB['upperband'] <= df['high']) \
             | ((BB['upperband'] - df['high'])/(BB['upperband']-BB['middleband']) <= bb_near_ratio )
            ).rolling(bb_window).sum() > 0,
           'Close' : (df['close'] < df['close'].shift() ),
        }
        
        sell = reduce(lambda a,b:a&b, conditions.values())
        
        if debug:
            print(f'{df}')
            print(f'{KD}')
            print(f'{BB}')
            print(f'{pd.DataFrame(conditions)}')
            print(f'{sell.iloc[-1]}')
    
        
        for ticket in open_position[open_position['symbol']==sid]['ticket']:
            openprice = open_position[open_position['ticket']==ticket]['openprice'].iloc[0]
            stoploss = open_position[open_position['ticket']==ticket]['stoploss'].iloc[0]
            print(f'ticket = {ticket}, open = {openprice}, SL= {stoploss}')
            if sell.iloc[-1]==True or stoploss >= openprice:
                if TrackStopLoss:
                    newstoploss=max(df['low'].iloc[-3:].min(),openprice)
                    print(f'{newstoploss}')
                    if mt.Set_sl_and_tp_for_position(ticket, newstoploss):
                        print(f'{__fname__} Move SL@{newstoploss} {sid} : {ticket} DONE !')
                    else:
                        print(f'{__fname__} Move SL@{newstoploss} {sid} : {ticket} FAIL !')
                else:
                    if mt.Close_position_by_ticket(ticket):
                        print(f'{__fname__} Close position {sid} : {ticket} DONE !')
                    else:
                        print(f'{__fname__} Close position {sid} : {ticket} FAIL !')

# %%
def RemoveOpenPositionEver(symbol_selected: list, strategy_name: str):
    open_position = mt.Get_all_open_positions()
    reduced_symbol = symbol_selected
    for symbol in symbol_selected:
        if ((open_position['symbol']==symbol) & (open_position['comment'] == strategy_name)).any():
            reduced_symbol.remove(symbol)

    return reduced_symbol

# %%
def Strategy__STOCK_BY_BBANDS_AND_KD():
    __fname__ = '[' + sys._getframe().f_code.co_name + ']'
    
    print(f'{__fname__} Refresh all Stocks ...')
    mt.RefreshRates(instruments=stocks,
                    timeframes=['D'], nbrofbars=30, period=10)
    
    print(f'{__fname__} Close trade ...')
    close_trade_Strategy__STOCK_HIT_BBANDS_UB(
        timeframe='D',
        nbrofbars=30,
        kd_window=5,
        bb_window=5,
        bb_near_ratio=0.1,
        TrackStopLoss=True,
        debug=False)

    
    print(f'{__fname__} Generating trade signals ...')
    signal_df = signal_gen_Strategy__STOCK_HIT_BBANDS_LB(
        stocks=stocks, 
        nbrofbars=30,
        kd_window=5,
        bb_window=5,
        bb_near_ratio=0.15,
        rr_ratio=1.0,
        min_price=10,
        debug=False)
    sid_selected = list(signal_df.columns[signal_df.iloc[-1].fillna(False)])
    
    print(f'{__fname__} Remove opend position from selected stocks ...')
    sid_selected_2 = RemoveOpenPositionEver(sid_selected, strategy_name = 'STOCK_HIT_BBANDS_LB')
    
    print(f'{__fname__} open trade ...')
    open_trade_Strategy__STOCK_HIT_BBANDS_LB(
        stocks = sid_selected_2,
        money = 10000,
        lotsize_limit=0.005,
        timeframe='D',
        nbrofbars=10,
        debug=False)
    
    return sid_selected, sid_selected_2

# %%
import datetime as dt
import pytz
tz = pytz.timezone('America/New_York')
print(tz)
# Out:
# America/New_York

# %%
import datetime as dt
import pytz
from dateutil.tz import tzlocal
from scheduler import Scheduler
from threading import Thread, Event
import time


def srv_tz_dst_compensate(src_dt):
    if src_dt.dst()==dt.timedelta(hours=0):
        return src_dt
    else:
        return src_dt-src_dt.dst()

class Strategy_Scheduler:

    def __init__(self, \
                 func,
                 trade_time_list: list = [dt.time(hour=9,minute=30,second=0),dt.time(hour=16,minute=0,second=0)], \
                 tz_srv : dt.timezone = dt.timezone(dt.timedelta(hours=+2)), \
                 tz_mrk : dt.timezone = pytz.timezone('America/New_York'), \
                 idle_second : int = 60*30,
                ):
        self.func            = func
        self.trade_time_list = trade_time_list
        self.tz_srv          = tz_srv
        self.tz_mrk          = tz_mrk
        self.idle_second     = idle_second
        self.trade_interval  = [0] * (len(trade_time_list)-1)
        self.ev = Event()

    def start(self, idle_second=None, end_date_mrk=None, debug=False):
        test_mode     = mt.CheckTestMode(with_break=True)
        if idle_second is not None:
            self.idle_second = idle_second

        def EXEC_LOOP(ev: Event):
            exec_times    = 0
            while not ev.is_set():
                now_srv        = dt.datetime.fromtimestamp(timestamp=mt.GetServerTime(),tz=pytz.utc).replace(tzinfo=self.tz_srv)
                now_mrk        = srv_tz_dst_compensate(now_srv.astimezone(self.tz_mrk))
                now_lca        = now_mrk.astimezone(tzlocal())
                trade_dt_list = [now_mrk.replace(hour=t.hour, minute=t.minute, second=t.second) for t in self.trade_time_list]
                for i in range(len(trade_dt_list)-1):
                    if  (now_mrk.weekday() < 5) \
                        and (now_mrk >= trade_dt_list[i]) \
                        and (now_mrk <  trade_dt_list[i+1]) :
                        if not self.trade_interval[i]:
                            exec_times=exec_times+1
                            print(f"\nStrategy[{self.func.__name__}] Scheduled")
                            print(f"@LocalTime ={now_lca.isoformat(timespec='seconds')}")
                            print(f"@ServerTime={now_srv.isoformat(timespec='seconds')}")
                            print(f"@MarketTime={now_mrk.isoformat(timespec='seconds')}")
                            print(f"exec_times = {exec_times}")
                            s1, s2 = self.func()
                            #if debug:
                            #    print(f'[DEBUG]:STRATEGY__STOCK_HIT_BBANDS_LB => selected = {s1}')
                            #    print(f'[DEBUG]:remove opend order => selected = {s2}')
                            self.trade_interval[i] = True
                    else:
                        self.trade_interval[i] = False
    
                print(f"Tick Finished @ServerTime {now_srv.isoformat(timespec='seconds')}")
                mt.Break()

                # early stop; used for MT4 Testing ending
                if end_date_mrk != None and \
                   now_mrk >= end_date_mrk.replace(tzinfo=self.tz_mrk):
                    print("End of session !")
                    self.ev.set()

                cnt = 0
                while cnt < self.idle_second and not ev.is_set():
                    cnt=cnt+1
                    time.sleep(1)

        self.ev.clear()
        self.schedule_thread = Thread(target=EXEC_LOOP, args=(self.ev,))
        self.schedule_thread.start()

    def stop(self):
        self.ev.set()
        self.schedule_thread.join()
        self.ev.clear()

# %%
scheduler = Strategy_Scheduler(func=Strategy__STOCK_BY_BBANDS_AND_KD, \
                               trade_time_list= [
                                   dt.time(hour=9,minute=30,second=0),
                                   dt.time(hour=10,minute=0,second=0),
                                   dt.time(hour=11,minute=0,second=0),
                                   dt.time(hour=12,minute=0,second=0),
                                   dt.time(hour=13,minute=0,second=0),
                                   dt.time(hour=14,minute=0,second=0),
                                   dt.time(hour=15,minute=0,second=0),
                                   dt.time(hour=16,minute=0,second=0)],
                               idle_second = 0
                              )

# %%
scheduler.stop()
# Out:
# Tick Finished @ServerTime 2024-02-29T16:39:11+02:00

# %%
scheduler.start(debug=True, end_date_mrk=dt.datetime.strptime('20240222','%Y%m%d'))

# %%
scheduler.start(debug=True, end_date_mrk=dt.datetime.now(tz=tzlocal()).astimezone(pytz.timezone('America/New_York')).replace(hour=15,minute=0,second=0))
# Out:
# Strategy[Strategy__STOCK_BY_BBANDS_AND_KD] Scheduled
# @LocalTime =2024-02-29T22:39:37+08:00
# @ServerTime=2024-02-29T16:39:37+02:00
# @MarketTime=2024-02-29T09:39:37-05:00
# exec_times = 1
# [Strategy__STOCK_BY_BBANDS_AND_KD] Refresh all Stocks ...
# [Strategy__STOCK_BY_BBANDS_AND_KD] Close trade ...
# [close_trade_Strategy__STOCK_HIT_BBANDS_UB]
# ticket = 17835855, open = 37.67, SL= 35.23
# ticket = 17835854, open = 59.64, SL= 55.34
# ticket = 17802788, open = 77.03, SL= 73.5
# [Strategy__STOCK_BY_BBANDS_AND_KD] Generating trade signals ...
# 100% 201/201 [00:32<00:00,  6.27it/s]
# [Strategy__STOCK_BY_BBANDS_AND_KD] Remove opend position from selected stocks ...
# [Strategy__STOCK_BY_BBANDS_AND_KD] open trade ...
# [open_trade_Strategy__STOCK_HIT_BBANDS_LB] #SONY ==============
# [open_trade_Strategy__STOCK_HIT_BBANDS_LB] lotsize = 30.00, openprice = 86.31, stoploss = 84.7
# =================================
#
# Tick Finished @ServerTime 2024-02-29T16:39:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:40:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:41:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:57+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:58+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:42:59+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:00+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:01+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:02+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:03+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:04+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:05+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:06+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:07+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:08+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:09+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:10+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:11+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:12+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:13+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:14+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:15+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:16+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:17+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:18+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:19+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:20+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:21+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:22+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:23+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:24+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:25+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:26+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:27+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:28+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:29+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:30+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:31+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:32+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:33+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:34+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:35+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:36+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:37+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:38+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:39+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:40+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:41+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:42+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:43+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:44+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:45+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:46+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:47+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:48+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:49+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:50+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:51+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:52+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:53+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:54+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:55+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:56+02:00
# Tick Finished @ServerTime 2024-02-29T16:43:57+02:00
# ...
# Tick Finished @ServerTime 2024-02-29T18:33:14+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:17+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:17+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:17+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:17+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:17+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:22+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:22+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:22+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:23+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:23+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:23+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:24+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:24+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:24+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:24+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:25+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:25+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:25+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:25+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:26+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:26+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:26+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:27+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:27+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:27+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:27+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:28+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:28+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:28+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:28+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:28+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:28+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:28+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:29+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:29+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:29+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:29+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:29+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:29+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:30+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:30+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:30+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:30+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:30+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:31+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:31+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:31+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:32+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:32+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:32+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:32+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:33+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:33+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:34+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:34+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:34+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:35+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:35+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:35+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:35+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:35+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:35+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:36+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:36+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:37+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:37+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:37+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:37+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:38+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:38+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:38+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:38+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:39+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:39+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:39+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:39+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:40+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:40+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:40+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:40+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:40+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:41+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:41+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:41+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:41+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:42+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:42+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:42+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:43+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:43+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:44+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:44+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:44+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:45+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:45+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:45+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:45+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:45+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:45+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:45+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:45+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:46+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:46+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:46+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:46+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:46+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:47+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:47+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:47+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:47+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:47+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:47+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:48+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:48+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:49+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:49+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:49+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:49+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:50+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:50+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:50+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:50+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:51+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:51+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:51+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:52+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:52+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:52+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:52+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:53+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:53+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:53+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:53+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:54+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:54+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:54+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:54+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:54+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:55+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:55+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:55+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:55+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:56+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:56+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:56+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:56+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:57+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:57+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:57+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:57+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:58+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:58+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:58+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:58+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:59+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:59+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:59+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:59+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:59+02:00
# Tick Finished @ServerTime 2024-02-29T18:33:59+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:00+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:00+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:00+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:00+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:00+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:00+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:01+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:01+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:01+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:02+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:02+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:02+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:02+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:03+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:03+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:03+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:04+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:04+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:04+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:04+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:05+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:05+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:05+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:05+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:05+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:05+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:06+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:06+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:06+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:06+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:06+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:07+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:07+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:07+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:07+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:07+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:07+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:08+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:08+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:08+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:08+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:08+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:09+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:09+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:10+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:10+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:10+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:10+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:11+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:11+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:11+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:11+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:12+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:12+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:12+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:13+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:13+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:13+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:13+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:13+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:13+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:14+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:14+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:14+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:14+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:15+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:16+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:17+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:17+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:17+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:18+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:19+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:20+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:21+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:22+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:22+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:22+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:23+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:23+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:24+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:24+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:24+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:25+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:25+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:25+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:25+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:26+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:26+02:00
# Tick Finished @ServerTime 2024-02-29T18:34:26+02:00

# %% [markdown]
# ## Backtest

# %%
mt.Break()

# %%
import datetime as dt
dt.datetime.strptime('20240216','%Y%m%d')

# %%
print(1)

# %%
mt.Get_last_tick_info('#AA')

# %%
import datetime as dt
import pytz
from dateutil.tz import tzlocal
timestamp = mt.GetServerTime()

print(dt.datetime.fromtimestamp(timestamp))
print(dt.datetime.fromtimestamp(timestamp, tz=tzlocal()))
print(dt.datetime.fromtimestamp(timestamp, tz=pytz.utc))
print(dt.datetime.fromtimestamp(timestamp, tz=dt.timezone(dt.timedelta(hours=2))))
print(dt.datetime.utcfromtimestamp(timestamp).replace(tzinfo=dt.timezone(dt.timedelta(hours=2))).astimezone(pytz.timezone('America/New_York')))

# %%
def srv_tz_dst_compensate(src_dt):
    if src_dt.dst()==dt.timedelta(hours=0):
        return src_dt
    else:
        return src_dt-src_dt.dst()

# %%
srv_tz_dst_compensate(dt.datetime.utcfromtimestamp(timestamp).replace(tzinfo=dt.timezone(dt.timedelta(hours=2))).astimezone(pytz.timezone('America/New_York')))

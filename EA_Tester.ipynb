# %%
from EACommunicator_API import EACommunicator_API
import sys
#
############################################
# ALL API
############################################
#
#
#    def Disconnect(self):
#    def Connect(self,
#                server: str = 'localhost',
#                port: int = 5555) -> bool:
#    def Check_connection(self) -> bool:
#    def IsConnected(self) -> bool:
#    def Get_instrument_info(self,
#                            instrument: str = 'EURUSD') -> dict:
#    def Update_instruments(self, selected=True) -> bool:
#    def Get_instruments(self, selected=True) ->list:
#    def Get_last_x_ticks_from_now(self,
#                                  instrument: str = 'EURUSD',
#                                  nbrofticks: int = 2000) -> np.array:
#    def Get_last_x_bars_from_now(self,
#                                 instrument: str = 'EURUSD',
#                                 timeframe: str = 'D1',
#                                 nbrofbars: int = 1000) -> np.array:
#    def Get_all_orders(self) -> pd.DataFrame:
#    def readCsv(self, inputCsvString):
#    def Get_all_open_positions(self) -> pd.DataFrame:
#    def Get_all_closed_positions(self) -> pd.DataFrame:
#    def Open_order(self,
#                   instrument: str = '',
#                   ordertype: str = 'buy',
#                   volume: float = 0.01,
#                   openprice: float = 0.0,
#                   slippage: int = 5,
#                   magicnumber: int = 0,
#                   stoploss: float = 0.0,
#                   takeprofit: float = 0.0,
#                   comment: str = '',
#                   market: bool = False
#                   ) -> int:
#    def Close_position_by_ticket(self,
#                                 ticket: int = 0) -> bool:
#    def Close_position_partial_by_ticket(self,
#                                         ticket: int = 0,
#                                         volume_to_close: float = 0.01) -> bool:
#    def Delete_order_by_ticket(self,
#                               ticket: int = 0) -> bool:
#    def Set_sl_and_tp_for_position(self,
#                                   ticket: int = 0,
#                                   stoploss: float = 0.0,
#                                   takeprofit: float = 0.0) -> bool:
#    def Set_sl_and_tp_for_order(self,
#                                ticket: int = 0,
#                                stoploss: float = 0.0,
#                                takeprofit: float = 0.0) -> bool:
#    def Change_settings_for_pending_order(self,
#                                ticket: int = 0,
#                                price: float = -1.0,
#                                stoploss: float = -1.0,
#                                takeprofit: float = -1.0) -> bool:
#    def Get_last_tick_info(self, symbol):
#    def send_command(self,
#                     command: TradingCommands, arguments: str = ''):
#    def get_timeframe_value(self,
#                            timeframe: str = 'M1') -> int:

# %%
mt = EACommunicator_API()
#mt.Connect(server='host.docker.internal')
mt.Connect(server='localhost', port=5555)

# %%
Symbols = mt.Get_instruments(False)
# Out:
# Retreive Tick of #AA failed ! Remove from symbol list.
# Retreive Tick of #AAL failed ! Remove from symbol list.
# Retreive Tick of #AAPL failed ! Remove from symbol list.
# Retreive Tick of #ABNB failed ! Remove from symbol list.
# Retreive Tick of #ABT failed ! Remove from symbol list.
# Retreive Tick of #ADBE failed ! Remove from symbol list.
# Retreive Tick of #ADS failed ! Remove from symbol list.
# Retreive Tick of #AI failed ! Remove from symbol list.
# Retreive Tick of #AIG failed ! Remove from symbol list.
# Retreive Tick of #AIR failed ! Remove from symbol list.
# Retreive Tick of #AIRP failed ! Remove from symbol list.
# Retreive Tick of #AKAM failed ! Remove from symbol list.
# Retreive Tick of #ALL failed ! Remove from symbol list.
# Retreive Tick of #ALV failed ! Remove from symbol list.
# Retreive Tick of #AMC failed ! Remove from symbol list.
# Retreive Tick of #AMZN failed ! Remove from symbol list.
# Retreive Tick of #ANF failed ! Remove from symbol list.
# Retreive Tick of #ATHM failed ! Remove from symbol list.
# Retreive Tick of #AXAF failed ! Remove from symbol list.
# Retreive Tick of #AXP failed ! Remove from symbol list.
# Retreive Tick of #BA failed ! Remove from symbol list.
# Retreive Tick of #BABA failed ! Remove from symbol list.
# Retreive Tick of #BAC failed ! Remove from symbol list.
# Retreive Tick of #BAS failed ! Remove from symbol list.
# Retreive Tick of #BAYN failed ! Remove from symbol list.
# Retreive Tick of #BB failed ! Remove from symbol list.
# Retreive Tick of #BBY failed ! Remove from symbol list.
# Retreive Tick of #BEI failed ! Remove from symbol list.
# Retreive Tick of #BEN failed ! Remove from symbol list.
# Retreive Tick of #BIDU failed ! Remove from symbol list.
# Retreive Tick of #BIIB failed ! Remove from symbol list.
# Retreive Tick of #BK failed ! Remove from symbol list.
# Retreive Tick of #BLK failed ! Remove from symbol list.
# Retreive Tick of #BMW failed ! Remove from symbol list.
# Retreive Tick of #BMY failed ! Remove from symbol list.
# Retreive Tick of #BNPP failed ! Remove from symbol list.
# Retreive Tick of #BOUY failed ! Remove from symbol list.
# Retreive Tick of #BRKb failed ! Remove from symbol list.
# Retreive Tick of #C failed ! Remove from symbol list.
# Retreive Tick of #CAT failed ! Remove from symbol list.
# Retreive Tick of #CBK failed ! Remove from symbol list.
# Retreive Tick of #CL failed ! Remove from symbol list.
# Retreive Tick of #CMCSA failed ! Remove from symbol list.
# Retreive Tick of #CMG failed ! Remove from symbol list.
# Retreive Tick of #COIN failed ! Remove from symbol list.
# Retreive Tick of #COMP failed ! Remove from symbol list.
# Retreive Tick of #COP failed ! Remove from symbol list.
# Retreive Tick of #COST failed ! Remove from symbol list.
# Retreive Tick of #COUR failed ! Remove from symbol list.
# Retreive Tick of #CPNG failed ! Remove from symbol list.
# Retreive Tick of #CRM failed ! Remove from symbol list.
# Retreive Tick of #CSCO failed ! Remove from symbol list.
# Retreive Tick of #CVS failed ! Remove from symbol list.
# Retreive Tick of #CVX failed ! Remove from symbol list.
# Retreive Tick of #DAI failed ! Remove from symbol list.
# Retreive Tick of #DAL failed ! Remove from symbol list.
# Retreive Tick of #DANO failed ! Remove from symbol list.
# Retreive Tick of #DASH failed ! Remove from symbol list.
# Retreive Tick of #DB1 failed ! Remove from symbol list.
# Retreive Tick of #DBK failed ! Remove from symbol list.
# Retreive Tick of #DBX failed ! Remove from symbol list.
# Retreive Tick of #DFS failed ! Remove from symbol list.
# Retreive Tick of #DIS failed ! Remove from symbol list.
# Retreive Tick of #DLTR failed ! Remove from symbol list.
# Retreive Tick of #DOCS failed ! Remove from symbol list.
# Retreive Tick of #DOCU failed ! Remove from symbol list.
# Retreive Tick of #DPW failed ! Remove from symbol list.
# Retreive Tick of #DTE failed ! Remove from symbol list.
# Retreive Tick of #DUK failed ! Remove from symbol list.
# Retreive Tick of #EBAY failed ! Remove from symbol list.
# Retreive Tick of #EON failed ! Remove from symbol list.
# Retreive Tick of #ETF-ARGT failed ! Remove from symbol list.
# Retreive Tick of #ETF-ASHR failed ! Remove from symbol list.
# Retreive Tick of #ETF-EEM failed ! Remove from symbol list.
# Retreive Tick of #ETF-EFA failed ! Remove from symbol list.
# Retreive Tick of #ETF-EIDO failed ! Remove from symbol list.
# Retreive Tick of #ETF-EPU failed ! Remove from symbol list.
# Retreive Tick of #ETF-EWT failed ! Remove from symbol list.
# Retreive Tick of #ETF-EWW failed ! Remove from symbol list.
# Retreive Tick of #ETF-EWZ failed ! Remove from symbol list.
# Retreive Tick of #ETF-EZA failed ! Remove from symbol list.
# Retreive Tick of #ETF-GDX failed ! Remove from symbol list.
# Retreive Tick of #ETF-GLD failed ! Remove from symbol list.
# Retreive Tick of #ETF-GXC failed ! Remove from symbol list.
# Retreive Tick of #ETF-ILF failed ! Remove from symbol list.
# Retreive Tick of #ETF-KSA failed ! Remove from symbol list.
# Retreive Tick of #ETF-SMIN failed ! Remove from symbol list.
# Retreive Tick of #ETF-USO failed ! Remove from symbol list.
# Retreive Tick of #ETF-VNM failed ! Remove from symbol list.
# Retreive Tick of #ETF-VTI failed ! Remove from symbol list.
# Retreive Tick of #ETF-VUG failed ! Remove from symbol list.
# Retreive Tick of #ETF-XLE failed ! Remove from symbol list.
# Retreive Tick of #ETF-XLF failed ! Remove from symbol list.
# Retreive Tick of #ETF-XLK failed ! Remove from symbol list.
# Retreive Tick of #F failed ! Remove from symbol list.
# Retreive Tick of #FB failed ! Remove from symbol list.
# Retreive Tick of #FDX failed ! Remove from symbol list.
# Retreive Tick of #FME failed ! Remove from symbol list.
# Retreive Tick of #FSLY failed ! Remove from symbol list.
# Retreive Tick of #GDDY failed ! Remove from symbol list.
# Retreive Tick of #GE failed ! Remove from symbol list.
# Retreive Tick of #GILD failed ! Remove from symbol list.
# Retreive Tick of #GM failed ! Remove from symbol list.
# Retreive Tick of #GME failed ! Remove from symbol list.
# Retreive Tick of #GOOG failed ! Remove from symbol list.
# Retreive Tick of #GS failed ! Remove from symbol list.
# Retreive Tick of #HAL failed ! Remove from symbol list.
# Retreive Tick of #HAYW failed ! Remove from symbol list.
# Retreive Tick of #HD failed ! Remove from symbol list.
# Retreive Tick of #HK0001 failed ! Remove from symbol list.
# Retreive Tick of #HK0002 failed ! Remove from symbol list.
# Retreive Tick of #HK0005 failed ! Remove from symbol list.
# Retreive Tick of #HK0011 failed ! Remove from symbol list.
# Retreive Tick of #HK0012 failed ! Remove from symbol list.
# Retreive Tick of #HK0016 failed ! Remove from symbol list.
# Retreive Tick of #HK0017 failed ! Remove from symbol list.
# Retreive Tick of #HK0019 failed ! Remove from symbol list.
# Retreive Tick of #HK0066 failed ! Remove from symbol list.
# Retreive Tick of #HK0168 failed ! Remove from symbol list.
# Retreive Tick of #HK0175 failed ! Remove from symbol list.
# Retreive Tick of #HK0241 failed ! Remove from symbol list.
# Retreive Tick of #HK0291 failed ! Remove from symbol list.
# Retreive Tick of #HK0293 failed ! Remove from symbol list.
# Retreive Tick of #HK0322 failed ! Remove from symbol list.
# Retreive Tick of #HK0388 failed ! Remove from symbol list.
# Retreive Tick of #HK0392 failed ! Remove from symbol list.
# Retreive Tick of #HK0489 failed ! Remove from symbol list.
# Retreive Tick of #HK0656 failed ! Remove from symbol list.
# Retreive Tick of #HK0688 failed ! Remove from symbol list.
# Retreive Tick of #HK0700 failed ! Remove from symbol list.
# Retreive Tick of #HK0763 failed ! Remove from symbol list.
# Retreive Tick of #HK0772 failed ! Remove from symbol list.
# Retreive Tick of #HK0813 failed ! Remove from symbol list.
# Retreive Tick of #HK0868 failed ! Remove from symbol list.
# Retreive Tick of #HK0881 failed ! Remove from symbol list.
# Retreive Tick of #HK0914 failed ! Remove from symbol list.
# Retreive Tick of #HK0939 failed ! Remove from symbol list.
# Retreive Tick of #HK1024 failed ! Remove from symbol list.
# Retreive Tick of #HK1044 failed ! Remove from symbol list.
# Retreive Tick of #HK1088 failed ! Remove from symbol list.
# Retreive Tick of #HK1109 failed ! Remove from symbol list.
# Retreive Tick of #HK1299 failed ! Remove from symbol list.
# Retreive Tick of #HK1398 failed ! Remove from symbol list.
# Retreive Tick of #HK1658 failed ! Remove from symbol list.
# Retreive Tick of #HK1810 failed ! Remove from symbol list.
# Retreive Tick of #HK1918 failed ! Remove from symbol list.
# Retreive Tick of #HK1929 failed ! Remove from symbol list.
# Retreive Tick of #HK2020 failed ! Remove from symbol list.
# Retreive Tick of #HK2318 failed ! Remove from symbol list.
# Retreive Tick of #HK2388 failed ! Remove from symbol list.
# Retreive Tick of #HK2628 failed ! Remove from symbol list.
# Retreive Tick of #HK3188 failed ! Remove from symbol list.
# Retreive Tick of #HK3328 failed ! Remove from symbol list.
# Retreive Tick of #HK3333 failed ! Remove from symbol list.
# Retreive Tick of #HK6862 failed ! Remove from symbol list.
# Retreive Tick of #HK9618 failed ! Remove from symbol list.
# Retreive Tick of #HK9633 failed ! Remove from symbol list.
# Retreive Tick of #HK9988 failed ! Remove from symbol list.
# Retreive Tick of #HLT failed ! Remove from symbol list.
# Retreive Tick of #HOG failed ! Remove from symbol list.
# Retreive Tick of #HON failed ! Remove from symbol list.
# Retreive Tick of #HPQ failed ! Remove from symbol list.
# Retreive Tick of #HRMS failed ! Remove from symbol list.
# Retreive Tick of #IBM failed ! Remove from symbol list.
# Retreive Tick of #IFX failed ! Remove from symbol list.
# Retreive Tick of #ILMN failed ! Remove from symbol list.
# Retreive Tick of #INTC failed ! Remove from symbol list.
# Retreive Tick of #JD failed ! Remove from symbol list.
# Retreive Tick of #JNJ failed ! Remove from symbol list.
# Retreive Tick of #JPM failed ! Remove from symbol list.
# Retreive Tick of #KHC failed ! Remove from symbol list.
# Retreive Tick of #KO failed ! Remove from symbol list.
# Retreive Tick of #L failed ! Remove from symbol list.
# Retreive Tick of #LHA failed ! Remove from symbol list.
# Retreive Tick of #LI failed ! Remove from symbol list.
# Retreive Tick of #LIN failed ! Remove from symbol list.
# Retreive Tick of #LLY failed ! Remove from symbol list.
# Retreive Tick of #LMND failed ! Remove from symbol list.
# Retreive Tick of #LMT failed ! Remove from symbol list.
# Retreive Tick of #LU failed ! Remove from symbol list.
# Retreive Tick of #LUV failed ! Remove from symbol list.
# Retreive Tick of #LVMH failed ! Remove from symbol list.
# Retreive Tick of #LVS failed ! Remove from symbol list.
# Retreive Tick of #LYFT failed ! Remove from symbol list.
# Retreive Tick of #MA failed ! Remove from symbol list.
# Retreive Tick of #MAR failed ! Remove from symbol list.
# Retreive Tick of #MCD failed ! Remove from symbol list.
# Retreive Tick of #MCO failed ! Remove from symbol list.
# Retreive Tick of #MET failed ! Remove from symbol list.
# Retreive Tick of #MGM failed ! Remove from symbol list.
# Retreive Tick of #MICP failed ! Remove from symbol list.
# Retreive Tick of #MMM failed ! Remove from symbol list.
# Retreive Tick of #MO failed ! Remove from symbol list.
# Retreive Tick of #MRK failed ! Remove from symbol list.
# Retreive Tick of #MRNA failed ! Remove from symbol list.
# Retreive Tick of #MS failed ! Remove from symbol list.
# Retreive Tick of #MSFT failed ! Remove from symbol list.
# Retreive Tick of #MSI failed ! Remove from symbol list.
# Retreive Tick of #MUV2 failed ! Remove from symbol list.
# Retreive Tick of #NFLX failed ! Remove from symbol list.
# Retreive Tick of #NIO failed ! Remove from symbol list.
# Retreive Tick of #NKE failed ! Remove from symbol list.
# Retreive Tick of #NOK failed ! Remove from symbol list.
# Retreive Tick of #NRG failed ! Remove from symbol list.
# Retreive Tick of #NTES failed ! Remove from symbol list.
# Retreive Tick of #NVDA failed ! Remove from symbol list.
# Retreive Tick of #OLED failed ! Remove from symbol list.
# Retreive Tick of #OLO failed ! Remove from symbol list.
# Retreive Tick of #OMC failed ! Remove from symbol list.
# Retreive Tick of #ORCL failed ! Remove from symbol list.
# Retreive Tick of #OREP failed ! Remove from symbol list.
# Retreive Tick of #PATH failed ! Remove from symbol list.
# Retreive Tick of #PBR failed ! Remove from symbol list.
# Retreive Tick of #PCOR failed ! Remove from symbol list.
# Retreive Tick of #PDD failed ! Remove from symbol list.
# Retreive Tick of #PEP failed ! Remove from symbol list.
# Retreive Tick of #PFE failed ! Remove from symbol list.
# Retreive Tick of #PG failed ! Remove from symbol list.
# Retreive Tick of #PINS failed ! Remove from symbol list.
# Retreive Tick of #PM failed ! Remove from symbol list.
# Retreive Tick of #PNC failed ! Remove from symbol list.
# Retreive Tick of #PRU failed ! Remove from symbol list.
# Retreive Tick of #PYPL failed ! Remove from symbol list.
# Retreive Tick of #QCOM failed ! Remove from symbol list.
# Retreive Tick of #RACE failed ! Remove from symbol list.
# Retreive Tick of #RBLX failed ! Remove from symbol list.
# Retreive Tick of #RWE failed ! Remove from symbol list.
# Retreive Tick of #SAP failed ! Remove from symbol list.
# Retreive Tick of #SBUX failed ! Remove from symbol list.
# Retreive Tick of #SCHW failed ! Remove from symbol list.
# Retreive Tick of #SHAK failed ! Remove from symbol list.
# Retreive Tick of #SHOP failed ! Remove from symbol list.
# Retreive Tick of #SIE failed ! Remove from symbol list.
# Retreive Tick of #SNAP failed ! Remove from symbol list.
# Retreive Tick of #SNOW failed ! Remove from symbol list.
# Retreive Tick of #SONY failed ! Remove from symbol list.
# Retreive Tick of #SQ failed ! Remove from symbol list.
# Retreive Tick of #SQSP failed ! Remove from symbol list.
# Retreive Tick of #T failed ! Remove from symbol list.
# Retreive Tick of #TGT failed ! Remove from symbol list.
# Retreive Tick of #TLRY failed ! Remove from symbol list.
# Retreive Tick of #TM failed ! Remove from symbol list.
# Retreive Tick of #TME failed ! Remove from symbol list.
# Retreive Tick of #TMUS failed ! Remove from symbol list.
# Retreive Tick of #TRIP failed ! Remove from symbol list.
# Retreive Tick of #TSM failed ! Remove from symbol list.
# Retreive Tick of #TSN failed ! Remove from symbol list.
# Retreive Tick of #TTEF failed ! Remove from symbol list.
# Retreive Tick of #TUYA failed ! Remove from symbol list.
# Retreive Tick of #TWLO failed ! Remove from symbol list.
# Retreive Tick of #U failed ! Remove from symbol list.
# Retreive Tick of #UAL failed ! Remove from symbol list.
# Retreive Tick of #UBER failed ! Remove from symbol list.
# Retreive Tick of #UGI failed ! Remove from symbol list.
# Retreive Tick of #UPS failed ! Remove from symbol list.
# Retreive Tick of #V failed ! Remove from symbol list.
# Retreive Tick of #VALE failed ! Remove from symbol list.
# Retreive Tick of #VIPS failed ! Remove from symbol list.
# Retreive Tick of #VOW failed ! Remove from symbol list.
# Retreive Tick of #VRSN failed ! Remove from symbol list.
# Retreive Tick of #VZ failed ! Remove from symbol list.
# Retreive Tick of #W failed ! Remove from symbol list.
# Retreive Tick of #WB failed ! Remove from symbol list.
# Retreive Tick of #WBA failed ! Remove from symbol list.
# Retreive Tick of #WDAY failed ! Remove from symbol list.
# Retreive Tick of #WFC failed ! Remove from symbol list.
# Retreive Tick of #WMT failed ! Remove from symbol list.
# Retreive Tick of #WYNN failed ! Remove from symbol list.
# Retreive Tick of #XOM failed ! Remove from symbol list.
# Retreive Tick of #XPEV failed ! Remove from symbol list.
# Retreive Tick of #YELP failed ! Remove from symbol list.
# Retreive Tick of #ZM failed ! Remove from symbol list.
# Retreive Tick of ADAUSD failed ! Remove from symbol list.
# Retreive Tick of AUDCAD failed ! Remove from symbol list.
# Retreive Tick of AUDCHF failed ! Remove from symbol list.
# Retreive Tick of AUDJPY failed ! Remove from symbol list.
# Retreive Tick of AUDNZD failed ! Remove from symbol list.
# Retreive Tick of AUDUSD failed ! Remove from symbol list.
# Retreive Tick of AUS200 failed ! Remove from symbol list.
# Retreive Tick of BCHUSD failed ! Remove from symbol list.
# Retreive Tick of BNBUSD failed ! Remove from symbol list.
# Retreive Tick of BRENT failed ! Remove from symbol list.
# Retreive Tick of BTCUSD failed ! Remove from symbol list.
# Retreive Tick of CADCHF failed ! Remove from symbol list.
# Retreive Tick of CADJPY failed ! Remove from symbol list.
# Retreive Tick of CHFJPY failed ! Remove from symbol list.
# Retreive Tick of CHI50 failed ! Remove from symbol list.
# Retreive Tick of DOGUSD failed ! Remove from symbol list.
# Retreive Tick of DOTUSD failed ! Remove from symbol list.
# Retreive Tick of ESP35 failed ! Remove from symbol list.
# Retreive Tick of ETHUSD failed ! Remove from symbol list.
# Retreive Tick of EU50 failed ! Remove from symbol list.
# Retreive Tick of EURAUD failed ! Remove from symbol list.
# Retreive Tick of EURCAD failed ! Remove from symbol list.
# Retreive Tick of EURCHF failed ! Remove from symbol list.
# Retreive Tick of EURGBP failed ! Remove from symbol list.
# Retreive Tick of EURHUF failed ! Remove from symbol list.
# Retreive Tick of EURJPY failed ! Remove from symbol list.
# Retreive Tick of EURNZD failed ! Remove from symbol list.
# Retreive Tick of EURPLN failed ! Remove from symbol list.
# Retreive Tick of EURUSD failed ! Remove from symbol list.
# Retreive Tick of FRA40 failed ! Remove from symbol list.
# Retreive Tick of GBPAUD failed ! Remove from symbol list.
# Retreive Tick of GBPCAD failed ! Remove from symbol list.
# Retreive Tick of GBPCHF failed ! Remove from symbol list.
# Retreive Tick of GBPJPY failed ! Remove from symbol list.
# Retreive Tick of GBPNZD failed ! Remove from symbol list.
# Retreive Tick of GBPUSD failed ! Remove from symbol list.
# Retreive Tick of GER30 failed ! Remove from symbol list.
# Retreive Tick of GOLD_APR24 failed ! Remove from symbol list.
# Retreive Tick of HG_MAY24 failed ! Remove from symbol list.
# Retreive Tick of HK50 failed ! Remove from symbol list.
# Retreive Tick of HKCH50 failed ! Remove from symbol list.
# Retreive Tick of IT40 failed ! Remove from symbol list.
# Retreive Tick of JP225 failed ! Remove from symbol list.
# Retreive Tick of LNKUSD failed ! Remove from symbol list.
# Retreive Tick of LTCUSD failed ! Remove from symbol list.
# Retreive Tick of NAS100 failed ! Remove from symbol list.
# Retreive Tick of NGAS.APR24 failed ! Remove from symbol list.
# Retreive Tick of NZDCAD failed ! Remove from symbol list.
# Retreive Tick of NZDCHF failed ! Remove from symbol list.
# Retreive Tick of NZDJPY failed ! Remove from symbol list.
# Retreive Tick of NZDUSD failed ! Remove from symbol list.
# Retreive Tick of SPX500 failed ! Remove from symbol list.
# Retreive Tick of UK100 failed ! Remove from symbol list.
# Retreive Tick of UKOIL.APR24 failed ! Remove from symbol list.
# Retreive Tick of UKOIL.MAY24 failed ! Remove from symbol list.
# Retreive Tick of UNIUSD failed ! Remove from symbol list.
# Retreive Tick of US2000 failed ! Remove from symbol list.
# Retreive Tick of US30 failed ! Remove from symbol list.
# Retreive Tick of USDCAD failed ! Remove from symbol list.
# Retreive Tick of USDCHF failed ! Remove from symbol list.
# Retreive Tick of USDCNH failed ! Remove from symbol list.
# Retreive Tick of USDCZK failed ! Remove from symbol list.
# Retreive Tick of USDDKK failed ! Remove from symbol list.
# Retreive Tick of USDHKD failed ! Remove from symbol list.
# Retreive Tick of USDHUF failed ! Remove from symbol list.
# Retreive Tick of USDJPY failed ! Remove from symbol list.
# Retreive Tick of USDMXN failed ! Remove from symbol list.
# Retreive Tick of USDNOK failed ! Remove from symbol list.
# Retreive Tick of USDPLN failed ! Remove from symbol list.
# Retreive Tick of USDSEK failed ! Remove from symbol list.
# Retreive Tick of USDSGD failed ! Remove from symbol list.
# Retreive Tick of USDTRY failed ! Remove from symbol list.
# Retreive Tick of USDX failed ! Remove from symbol list.
# Retreive Tick of USDX_JUN24 failed ! Remove from symbol list.
# Retreive Tick of USDX_MAR24 failed ! Remove from symbol list.
# Retreive Tick of USDZAR failed ! Remove from symbol list.
# Retreive Tick of USOIL.APR24 failed ! Remove from symbol list.
# Retreive Tick of USOIL.MAY24 failed ! Remove from symbol list.
# Retreive Tick of WTI failed ! Remove from symbol list.
# Retreive Tick of XAGUSD failed ! Remove from symbol list.
# Retreive Tick of XAUEUR failed ! Remove from symbol list.
# Retreive Tick of XAUUSD failed ! Remove from symbol list.
# Retreive Tick of XLMUSD failed ! Remove from symbol list.

# %%
stocks=[]
for sid in mt.Symbols:
    if '#' in sid and '#ETF' not in sid and '#HK' not in sid:
        tick = mt.Get_last_tick_info(sid)
        #if tick['ask'] <= 100 and tick['ask'] > 50:
        stocks.append(sid)

# %%
#stocks = [
# '#AAPL','#ADBE', '#AMZN', '#BABA', '#COST', '#CPNG', '#EBAY', '#GOOG', '#IBM', '#INTC', '#JNJ', '#KO', 
# '#MMM', '#MO', '#MSFT',  '#NFLX', '#NKE',  '#NVDA',  '#PG',  '#QCOM',  '#SONY',  '#TSLA', '#TSM',  '#UBER',  '#WMT',  ]

#stocks = ['#AIG', '#BABA', '#BBY', '#BK', '#BMY', '#BNPP', '#C', '#CL', '#CVS', '#DAI',
# '#DANO', '#DOCU', '#DUK', '#GILD', '#KO', '#L', '#LVS', '#MET', '#MMM', '#MRNA',
# '#MS', '#NRG', '#OMC', '#PCOR', '#PM', '#PYPL', '#SBUX', '#SCHW', '#SHAK', '#SHOP',
# '#SONY', '#SQ', '#TSN', '#TTEF', '#TWLO', '#UBER', '#W', '#WFC', '#ZM']

#stocks = ['#C']


EU_shares = ['#ADS', '#AIR', '#AIRP', '#ALV', '#AXAF', '#BAS', '#BAYN', '#BEI',
             '#BMW', '#BNPP', '#BOUY', '#CBK', '#DAI', '#DANO', '#DB1', '#DBK', '#DPW', '#DTE',
             '#EON', '#FME', '#HRMS', '#IFX', '#LHA', '#LIN', '#LVMH', '#MICP', '#MUV2', '#OREP',
             '#RWE', '#SAP', '#SIE', '#TTEF', '#VOW']

for eu_sid in EU_shares:
    if eu_sid in stocks:
        stocks.remove(eu_sid)

stocks
# Out:
# ['#TSLA']

# %% [markdown]
# ## Strategy : Stock Hit BBands LB

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 100)

def Get_ohlcv(instrument='EURUSD', timeframe='D', nbrofbars=20):
    df = pd.DataFrame(mt.Get_last_x_bars_from_now(instrument, timeframe,nbrofbars))
    df = df.iloc[:, 1:].set_index('Time')
    df.index = pd.to_datetime(df.index)
    df.columns = [c.lower() for c in df.columns]
    return df

# %%
from functools import reduce
def recursive_reduce(cond_dict, conditions):
    def reduce_op(a,b):
        #print(f'OP = {a} {list(cond_dict.keys())[0]} {b}')
        if list(cond_dict.keys())[0]=='|':
            return a|b
        elif list(cond_dict.keys())[0]=='&':
            return a&b
        else:
            return False
    conds = []
    for cond in list(cond_dict.values())[0]:
        if type(cond) == dict:
            conds.append(recursive_reduce(cond, conditions))
        else:
            if cond in conditions:
                conds.append(conditions[cond])
            else:
                print(cond + ' is not in conditions!')
            
    if list(cond_dict.keys())[0]=='~':
        return ~conds[0]
    else:
        return reduce(reduce_op, conds)

# %%
from talib import abstract
from functools import reduce
from tqdm import tqdm
import sys
import datetime as dt

def signal_gen_Strategy__STOCK_HIT_BBANDS_LB(stocks, 
                                             nbrofbars=20,
                                             kd_window=5,
                                             bb_window=5,
                                             bb_near_ratio=0.1,
                                             rr_ratio=1.8,
                                             min_price=10,
                                             now_srv=None,
                                             debug=False):
    __fname__ = '[' + sys._getframe().f_code.co_name + ']'
    if debug:
        print(f'{__fname__}')

    signal = {}
    
    #for sid in stocks:
    for sid in tqdm(stocks):
        info = mt.Get_instrument_info(sid)
        tick = mt.Get_last_tick_info(sid)
        df = Get_ohlcv(instrument=sid, timeframe='D', nbrofbars=nbrofbars)
        KD = abstract.STOCH(df,fastk_period=9)
        BB = abstract.BBANDS(df, 21, 2.1, 2.1)
        

        def KD_bull_divergence(window=13,D_crs1_ub=20, D_crs2_lb=17,debug=False):
            # 2 crs up in window
            KD_diff = (KD['slowk']-KD['slowd'])
            KD_crs_up_pos = ((KD_diff > 0).astype(int).diff()>0)
            KD_crs_up_2 = KD_crs_up_pos.rolling(window).sum()>=2

            # crs up point bounding
            KD_crs_up_pos1 = (KD['slowd'] < D_crs1_ub) & KD_crs_up_pos
            KD_crs_up_pos2 = (KD['slowd'] > D_crs2_lb) & KD_crs_up_pos
            KD_crs_up_pos_order_id = pd.Series(np.nan, index=KD.index)
            KD_crs_up_pos_order_id[KD_crs_up_pos1] =  1
            KD_crs_up_pos_order_id[KD_crs_up_pos2] =  2
            KD_crs_up_pos_in_order = (KD_crs_up_pos_order_id.ffill() == 2) \
            & ((KD_crs_up_pos_order_id==1).rolling(window).sum() > 0) \
            & ((KD_crs_up_pos_order_id==2).rolling(window).sum() > 0)

            # crs up point D increase
            KD_crs_up_pos_d_inc = (KD['slowd'].where(KD_crs_up_pos1 | KD_crs_up_pos2).ffill())
            KD_crs_up_pos_d_inc_until = pd.Series(np.nan, index=KD.index)
            KD_crs_up_pos_d_inc_until[KD_crs_up_pos_d_inc.diff()>0] = True
            KD_crs_up_pos_d_inc_until = KD_crs_up_pos_d_inc_until.ffill()
            
            # crs up point low decrease 
            low_win5 = df['low'].rolling(5).min()
            KD_crs_up_pos_low_not_inc = (low_win5.where(KD_crs_up_pos1 | KD_crs_up_pos2).ffill())
            KD_crs_up_pos_low_not_inc_until = pd.Series(np.nan, index=KD.index)
            KD_crs_up_pos_low_not_inc_until[KD_crs_up_pos_low_not_inc.diff()<=0] = True
            KD_crs_up_pos_low_not_inc_until = KD_crs_up_pos_low_not_inc_until.ffill()

            if debug:
                print('KD_crs_up_pos')
                print(KD_crs_up_pos)
                print('KD_crs_up_2')
                print(KD_crs_up_2)
                print('KD_crs_up_pos1')
                print(KD_crs_up_pos1)
                print('KD_crs_up_pos2')
                print(KD_crs_up_pos2)
                print('KD_crs_up_pos_order_id')
                print(KD_crs_up_pos_order_id)
                print('KD_crs_up_pos_in_order')
                print(KD_crs_up_pos_in_order)
                print('KD_crs_up_pos_d_inc')
                print(KD_crs_up_pos_d_inc)
                print('KD_crs_up_pos_d_inc_until')
                print(KD_crs_up_pos_d_inc_until)
                print('KD_crs_up_pos_low_not_inc')
                print(KD_crs_up_pos_low_not_inc)
                print('KD_crs_up_pos_low_not_inc_until')
                print(KD_crs_up_pos_low_not_inc_until)

            return KD_crs_up_2 & KD_crs_up_pos_in_order & KD_crs_up_pos_d_inc_until & KD_crs_up_pos_low_not_inc_until
    
        conditions = {
            'KD_up_crs_D_lte20_win10' : ( \
                (KD['slowk'] <= KD['slowd']).shift() \
                & (KD['slowk'] > KD['slowd']) \
                & (KD['slowd'] <= 20) \
                & (((df['low'] - BB['lowerband'])/(BB['middleband']-BB['lowerband'])).shift() <= 0.15 )) \
            .rolling(10).sum() > 0,
            'KD_crs3_win10' : \
            ((((KD['slowk'] - KD['slowd']) >= 0).diff() != 0).rolling(10).sum() > 3) \
            & ((KD['slowd'] <= 20).rolling(10).sum() > 7),
            'KD_diff_pos' : (KD['slowk'] - KD['slowd']) >= 0,
            'KD_diff3' : (KD['slowk'] - KD['slowd']) >= 3,
            'KD_diff_inc' : (KD['slowk']-KD['slowd']).diff() > 0,
            'KD_diff_inc_win2' : ((KD['slowk']-KD['slowd']).diff() > 0).rolling(2).sum() >= 2,
            'KD_diff_lt3_win4_shift1' : ((KD['slowk']-KD['slowd']).abs() < 3.0).rolling(4).sum().shift() == 4,
            'KD_K_slope_pos' : KD['slowk'] > KD['slowk'].shift(),
            'KD_D_slope_pos' : KD['slowd'] > KD['slowd'].shift(),
            'KD_D_slope_pos3' : (KD['slowd'] > KD['slowd'].shift()).rolling(3).sum() == 3,
            'KD_D_slope_neg_win4_shift1' : (KD['slowd'] <= KD['slowd'].shift()).rolling(4).sum().shift() == 4,
            'KD_D_lt20_win4_shift1' : (KD['slowd'] < 20).rolling(4).sum().shift() == 4,
            'KD_D_inc6_win2' : (KD['slowd'] - KD['slowd'].shift(2)) >= 6,
            'KD_K_inc6' : (KD['slowk'] - KD['slowk'].shift()) >= 6,
            'KD_K_slope_gte5' : (KD['slowk'] - KD['slowk'].shift()) >= 5,
            'KD_K_slope_gte10' : (KD['slowk'] - KD['slowk'].shift()) >= 10,
            'KD_bull_divergence' : KD_bull_divergence(window=13,D_crs1_ub=20, D_crs2_lb=17,debug=debug),
            'KD_saturate_gt6' : KD['slowd'].rolling(6).max() < 20,
            'BB_nearLB_win' : ( \
                ((df['low'] - BB['lowerband'])/(BB['middleband']-BB['lowerband']) <= bb_near_ratio ) \
            ).rolling(bb_window).sum() > 0,
            'BB_nearLB' : \
                ((df['low'] - BB['lowerband'])/(BB['middleband']-BB['lowerband']) <= 0.7 ),
            'BB_RiskReward' : ( ((BB['upperband']-tick['ask'])/ (tick['ask']-df['low'].rolling(5).min()+tick['spread']*info['point']) ) >= rr_ratio ),
            'BB_nearLB_win13' : ( \
                (df['low'] <= BB['lowerband']) \
                | ((df['low'] - BB['lowerband'])/(BB['middleband']-BB['lowerband']) <= bb_near_ratio ) \
            ).rolling(13).sum() > 0,
            'close_min' : (df['close'] > min_price),
            'close_gt_close1' : (df['close'] > df['close'].shift() ),
            'close_gt_high1' : (df['close'] > df['high'].shift() ),
            'close_gt_close_open_avg1' : (df['close'] > ((df['close']+df['open'])/2).shift() ),
            'close_gt_high_low_avg1' : (df['close'] > ((df['high']+df['low'])/2).shift() ),
            'up_candle1' : (df['close'].shift() > df['open'].shift() ),
            'up_candle' : (df['close'] > df['open'] ),
            'now_srv_gt1500': now_srv.time() >= dt.time(15,0,0),
        }

        cond_dict = \
        {'|' : [
            {'&' : [
                {'|': [
                    {'&':['KD_up_crs_D_lte20_win10',
                          {'|':[
                              {'&': [{'|':['KD_D_lt20_win4_shift1','KD_diff_lt3_win4_shift1']}, 'KD_diff_pos','KD_D_inc6_win2','KD_diff_inc']},
                              #{'&': [{'~': [{'|':['KD_saturate_gt6''KD_crs3_win10']}]},{'|':['KD_diff3','KD_K_inc6']}, 'KD_K_slope_pos','KD_D_slope_pos']}
                              {'&': [{'~': [{'|':['KD_D_lt20_win4_shift1','KD_diff_lt3_win4_shift1']}]},'KD_diff_pos','KD_K_slope_pos', 'KD_D_slope_pos']}
                          ]}
                         ]}
                ]},
                'BB_RiskReward',
                'BB_nearLB',
                'close_min',
                {'|': [
                    {'&':['up_candle1','close_gt_high_low_avg1']},
                    {'&':[ {'~':[ 'up_candle1']}, {'|':['close_gt_high_low_avg1', 'up_candle']}, 'now_srv_gt1500'  ]}
                ]}
            ]},
        ]}

        if debug:
            KD['diff'] = KD['slowk'] - KD['slowd']
            KD['diff>0'] = (KD['diff']>0).astype(int)
            KD['(diff>0).diff'] = KD['diff>0'].diff()
            KD['(diff>0).diff>0'] = (KD['(diff>0).diff']>0)
            print(f'price\n{df}')
            print(f'KD\n{KD}')
            print(f'BB\n{BB}')
            print(f'{__fname__}\n{conditions["BB_RiskReward"]}')
            print(
                (KD['slowk'] <= KD['slowd']).shift() \
                & (KD['slowk'] > KD['slowd']) \
                & (KD['slowd'] <= 20)
            )
            print(
                (((df['low'] - BB['lowerband'])/(BB['middleband']-BB['lowerband'])))
            )
            print(
                (KD['slowk'] <= KD['slowd']).shift() \
                & (KD['slowk'] > KD['slowd']) \
                & (KD['slowd'] <= 20) \
                & (((df['low'] - BB['lowerband'])/(BB['middleband']-BB['lowerband']).shift()) <= 0.15 ))
            #print(f'{__fname__}  RR_ratio = ({BB["middleband"].iloc[-1]}-{df["close"].iloc[-1]})/({df["close"].iloc[-1]}-{df["low"].iloc[-5:].min()}) = {(BB["middleband"].iloc[-1]-df["close"].iloc[-1])/(df["close"].iloc[-1]-df["low"].iloc[-5:].min())}')
            print(f'RR_ratio = ',
                  f'({BB["upperband"].iloc[-1]:.5f}-{tick["ask"]:.5f})/({tick["ask"]:.5f}-{df["low"].iloc[-5:].min()}+{tick["spread"]*info["point"]:.5f}) = ',
                  (BB["upperband"].iloc[-1]-tick["ask"])/(tick["ask"]-df["low"].iloc[-5:].min()+tick['spread']*info['point']))
            for k,v in conditions.items():
                if type(v) == pd.Series:
                    print(f'{k} : {v.iloc[-1]}')
                else:
                    print(f'{k} : {v}')
        
        signal[sid] = recursive_reduce(cond_dict, conditions)
        #signal[sid] =  reduce(lambda a,b:a&b, [conditions[c] for c in cond_sum[0]])]
    
    signal_df = pd.DataFrame(signal)

    return signal_df

# %%
from datetime import datetime


def open_trade_Strategy__STOCK_HIT_BBANDS_LB(
    stocks,
    money = 1000,
    timeframe='D',
    nbrofbars=10,
    lotsize_limit=0.005,
    drop_vio_lotsize=False,
    comment = 'STOCK_HIT_BBANDS_LB',
    debug=False):

    __fname__ = '[' + sys._getframe().f_code.co_name + ']'
    money_each_order = money * lotsize_limit
    
    ticket = {}
    for sid in stocks:
        df = Get_ohlcv(instrument=sid, timeframe=timeframe, nbrofbars=nbrofbars)
        print(f'{__fname__} {sid} ==============')
        info = mt.Get_instrument_info(sid)
        tick = mt.Get_last_tick_info(sid)
        ask = tick['ask']
        lowest = df['low'].iloc[-5:].min()
        risk = max(ask - lowest + info['point']*tick['spread'] , info['stop_level']*info['point'], 1)
        stoploss = ask - risk
        #lotsize = max(money_each_order / risk //info['lot_step'] *info['lot_step'] , info['min_lotsize'])
        lotsize = money_each_order / risk //info['lot_step'] *info['lot_step']
        if debug:
            print(f'{__fname__} info = {info}')
            print(f'{__fname__} tick = {tick}')
            print(f'{__fname__} ask = {ask}, lowest = {lowest}')
        print(f'{__fname__} lotsize = {lotsize:.2f}, openprice = {ask}, stoploss = {stoploss}')
        if drop_vio_lotsize:
            print(f'lotsize is too small to open trade !')
            return
        else:
            lotsize = max(info['min_lotsize'], lotsize)
            
        ticket[sid] =  mt.Open_order(
            instrument = sid,
            ordertype = 'buy',
            volume = lotsize,
            openprice = ask,
            slippage = 3,
            stoploss= stoploss,
            takeprofit= 0,
            comment = comment)
            
        print(f'=================================')
        print()

# %%
from datetime import datetime


def close_trade_Strategy__STOCK_HIT_BBANDS_UB(
    timeframe='D',
    nbrofbars=30,
    kd_window=5,
    bb_window=5,
    bb_near_ratio=0.1,
    TrackStopLoss=None,
    debug=False):

    __fname__ = '[' + sys._getframe().f_code.co_name + ']'
    print(f'{__fname__}')
    open_position = mt.Get_all_open_positions()

    for sid in open_position['symbol'].drop_duplicates():
        info = mt.Get_instrument_info(sid)
        tick = mt.Get_last_tick_info(sid)
        df = Get_ohlcv(instrument=sid, timeframe=timeframe, nbrofbars=nbrofbars)
        KD = abstract.STOCH(df,fastk_period=9)
        BB = abstract.BBANDS(df, 21, 2.1, 2.1)
        
    
        conditions = {
           'KD' : ( \
               (KD['slowk'] >= KD['slowd']).shift() \
             & (KD['slowk'] < KD['slowd']) \
             & (KD['slowd'] >= 80) \
           ).rolling(kd_window).sum()>0,
           'BB_NearUB' :  ( \
               (BB['upperband'] <= df['high']) \
             | ((BB['upperband'] - df['high'])/(BB['upperband']-BB['middleband']) <= bb_near_ratio )
            ).rolling(bb_window).sum() > 0,
           'Close' : (df['close'] < df['close'].shift() ),
            'SMA_up4': (BB['middleband'].diff()>0).rolling(4).sum() == 4,
        }

        cond_dict = {'&':[
            'KD',
            'BB_NearUB',
            'Close',
        ]}
        
        sell = recursive_reduce(cond_dict, conditions)
        
        if debug:
            print(f'{df}')
            print(f'{KD}')
            print(f'{BB}')
            print(f'{pd.DataFrame(conditions)}')
            print(f'{sell.iloc[-1]}')
    
        
        for ticket in open_position[open_position['symbol']==sid]['ticket']:
            openprice = open_position[open_position['ticket']==ticket]['openprice'].iloc[0]
            stoploss = open_position[open_position['ticket']==ticket]['stoploss'].iloc[0]
            print(f'ticket = {ticket}, open = {openprice}, SL= {stoploss}')
            if sell.iloc[-1]==True or stoploss >= openprice:
                if TrackStopLoss is not None:
                    newstoploss = 0
                    if TrackStopLoss == 1: # nearest 3 bar
                        newstoploss=max(df['low'].iloc[-3:].min(),openprice)
                    elif TrackStopLoss == 2:
                        hl_max = df[['high','low']].max(axis=1)
                        hl_min = df[['high','low']].min(axis=1)
                        hl_ovlp = (hl_min < hl_max.shift()) & (hl_max > hl_min.shift())
                        hl_ovlp_grp = (~hl_ovlp).cumsum()
                        hl_1st_grp_min = df['low'].loc[hl_ovlp_grp==hl_ovlp_grp.iloc[-2]].min()
                        hl_grp_sta_m1 = (~hl_ovlp).iloc[:-1].shift(-1).fillna(False)
                        if hl_grp_sta_m1.any():
                            hl_2nd_grp_last_min = df['low'].iloc[:-1].loc[hl_grp_sta_m1].iloc[-1]
                        else:
                            hl_2nd_grp_last_min = hl_1st_grp_min
                        #hl_grp_max = hl_max.iloc[:-1].groupby(by=hl_ovlp_grp.iloc[:-1]).max()

                        oc_max = df[['open','close']].max(axis=1)
                        oc_min = df[['open','close']].min(axis=1)
                        oc_ovlp = (oc_min < oc_max.shift()) & (oc_max > oc_min.shift())
                        oc_ovlp_grp = (~oc_ovlp).cumsum()
                        oc_1st_grp_min = df['low'].loc[oc_ovlp_grp==oc_ovlp_grp.iloc[-2]].min()
                        oc_grp_sta_m1 = (~oc_ovlp).iloc[:-1].shift(-1).fillna(False)
                        if oc_grp_sta_m1.any():
                            oc_2nd_grp_last_min = df['low'].iloc[:-1].loc[oc_grp_sta_m1].iloc[-1]
                        else:
                            oc_2nd_grp_last_min = oc_1st_grp_min
                        #oc_grp_max = oc_max.iloc[:-1].groupby(by=oc_ovlp_grp.iloc[:-1]).max()

                        if hl_ovlp_grp.iloc[-10:-1].nunique() == 1:
                            #if oc_ovlp_grp.nunique() == 1:
                            #    newstoploss = df['low'].iloc[-3:].min()
                            #else:
                                #newstoploss = oc_grp_max.iloc[-2]
                            newstoploss = min(oc_1st_grp_min, oc_2nd_grp_last_min)
                        else:
                            #if hl_ovlp_grp.nunique() == 1:
                            #    newstoploss = df['low'].iloc[-3:].min()
                            #else:
                                #newstoploss = hl_grp_max.iloc[-2]
                            newstoploss = min(hl_1st_grp_min, hl_2nd_grp_last_min)
                        newstoploss=max(openprice, stoploss, newstoploss-tick['spread']*info['point'])
                    elif TrackStopLoss == 3:
                        if ~((BB['middleband'].iloc[-4:].diff() > 0).all() and KD['slowk'] > 20):
                            newstoploss=max(df['low'].iloc[-3:].min(),openprice)
                            print('********************')
                            print('move stoploss')
                            print('********************')
                        
                    print(f'{newstoploss}')
                    if mt.Set_sl_and_tp_for_position(ticket, newstoploss):
                        print(f'{__fname__} Move SL@{newstoploss} {sid} : {ticket} DONE !')
                    else:
                        print(f'{__fname__} Move SL@{newstoploss} {sid} : {ticket} FAIL !')
                else:
                    if mt.Close_position_by_ticket(ticket):
                        print(f'{__fname__} Close position {sid} : {ticket} DONE !')
                    else:
                        print(f'{__fname__} Close position {sid} : {ticket} FAIL !')

# %%
import datetime as dt

def RemoveOpenPositionEver(symbol_selected: list, strategy_name: str, now_srv: dt=None, debug: bool=False):
    open_position = mt.Get_all_open_positions()
    close_position = mt.Get_all_closed_positions()
    reduced_symbol = symbol_selected[:]
    print(f'[RemoveOpenPositionEver:ALL_SRC_SYMBOL] => {symbol_selected}')
    for symbol in symbol_selected:
            
        if ((open_position['symbol']==symbol) & (open_position['comment'].str.startswith(strategy_name))).any():
            reduced_symbol.remove(symbol)
            if debug:
                print(f'[RemoveOpenPositionEver:OPEN] => {symbol}, {strategy_name}')
                print(open_position)
                print(open_position['symbol']==symbol) 
                print(open_position['comment'].str.startswith(strategy_name))
                print(((open_position['symbol']==symbol) & (open_position['comment'].str.startswith(strategy_name))))
                print(((open_position['symbol']==symbol) & (open_position['comment'].str.startswith(strategy_name))).any())
        elif now_srv is not None:
            today_srv = now_srv.strftime('%Y.%m.%d')
            if debug:
                print(f'[RemoveOpenPositionEver:CLOSE] => {symbol}, {strategy_name}, {today_srv}')
                print(close_position)
                print(close_position['symbol']==symbol) 
                print(close_position['comment'].str.startswith(strategy_name))
                #print(close_position['opentime']==today_srv)
                print(close_position['closetime']==today_srv)
            if ((close_position['symbol']==symbol) & (close_position['comment'].str.startswith(strategy_name)) & (close_position['opentime']==today_srv)).any() :
                reduced_symbol.remove(symbol)

    print(f'[RemoveOpenPositionEver:REDUCED_SYMBOL] => {reduced_symbol}')
    return reduced_symbol

# %%
def Strategy__STOCK_BY_BBANDS_AND_KD(now_srv=None):
    __fname__ = '[' + sys._getframe().f_code.co_name + ']'
    comment='STOCK_HIT_BBANDS_LB'
    
    print(f'{__fname__} Refresh all Stocks ...')
    mt.RefreshRates(instruments=stocks,
                    timeframes=['D'], nbrofbars=30, period=10)
    
    print(f'{__fname__} Close trade ...')
    close_trade_Strategy__STOCK_HIT_BBANDS_UB(
        timeframe='D',
        nbrofbars=30,
        kd_window=5,
        bb_window=5,
        bb_near_ratio=0.1,
        TrackStopLoss=2,
        debug=False)

    
    print(f'{__fname__} Generating trade signals ...')
    signal_df = signal_gen_Strategy__STOCK_HIT_BBANDS_LB(
        stocks=stocks, 
        nbrofbars=30,
        kd_window=5,
        bb_window=5,
        bb_near_ratio=0.15,
        rr_ratio=2.0,
        min_price=10,
        now_srv=now_srv,
        debug=False)
    sid_selected = list(signal_df.columns[signal_df.iloc[-1].fillna(False)])
    
    print(f'{__fname__} Remove opend position from selected stocks ...')
    sid_selected_2 = RemoveOpenPositionEver(sid_selected, strategy_name = comment, now_srv=now_srv, debug=False)
    
    print(f'{__fname__} open trade ...')
    open_trade_Strategy__STOCK_HIT_BBANDS_LB(
        stocks = sid_selected_2,
        money = 10000,
        lotsize_limit=0.005,
        drop_vio_lotsize=False,
        timeframe='D',
        nbrofbars=10,
        debug=False)
    
    return sid_selected, sid_selected_2

# %%
import datetime as dt
import pytz
from dateutil.tz import tzlocal
from threading import Thread, Event
import time


def srv_tz_dst_compensate(src_dt):
    if src_dt.dst()==dt.timedelta(hours=0):
        return src_dt
    else:
        return src_dt-src_dt.dst()

class Strategy_Scheduler:

    def __init__(self, \
                 func,
                 trade_time_list: list = [dt.time(hour=9,minute=30,second=0),dt.time(hour=16,minute=0,second=0)], \
                 tz_srv : dt.timezone = dt.timezone(dt.timedelta(hours=+2)), \
                 tz_mrk : dt.timezone = pytz.timezone('America/New_York'), \
                 idle_second : int = 60*30,
                ):
        self.func            = func
        self.trade_time_list = trade_time_list
        self.tz_srv          = tz_srv
        self.tz_mrk          = tz_mrk
        self.idle_second     = idle_second
        self.trade_interval  = [0] * (len(trade_time_list)-1)
        self.ev = Event()

    def start(self, idle_second=None, end_date_mrk=None, debug=False):
        test_mode     = mt.CheckTestMode(with_break=True)
        if idle_second is not None:
            self.idle_second = idle_second

        def EXEC_LOOP(ev: Event):
            exec_times    = 0
            while not ev.is_set():
                now_srv        = dt.datetime.fromtimestamp(timestamp=mt.GetServerTime(),tz=pytz.utc).replace(tzinfo=self.tz_srv)
                now_mrk        = srv_tz_dst_compensate(now_srv.astimezone(self.tz_mrk))
                now_lca        = now_mrk.astimezone(tzlocal())
                trade_dt_list = [now_mrk.replace(hour=t.hour, minute=t.minute, second=t.second) for t in self.trade_time_list]
                for i in range(len(trade_dt_list)-1):
                    if  (now_mrk.weekday() < 5) \
                        and (now_mrk >= trade_dt_list[i]) \
                        and (now_mrk <  trade_dt_list[i+1]) :
                        if not self.trade_interval[i]:
                            exec_times=exec_times+1
                            print(f"\nStrategy[{self.func.__name__}] Scheduled")
                            print(f"@LocalTime ={now_lca.isoformat(timespec='seconds')}")
                            print(f"@ServerTime={now_srv.isoformat(timespec='seconds')}")
                            print(f"@MarketTime={now_mrk.isoformat(timespec='seconds')}")
                            print(f"exec_times = {exec_times}")
                            kwargs = {'now_srv': now_srv}
                            s1, s2 = self.func(**kwargs)
                            #if debug:
                            #    print(f'[DEBUG]:STRATEGY__STOCK_HIT_BBANDS_LB => selected = {s1}')
                            #    print(f'[DEBUG]:remove opend order => selected = {s2}')
                            self.trade_interval[i] = True
                    else:
                        self.trade_interval[i] = False
    
                print(f"Tick Finished @ServerTime {now_srv.isoformat(timespec='seconds')}")
                mt.Break()

                # early stop; used for MT4 Testing ending
                if end_date_mrk != None and \
                   now_mrk >= end_date_mrk.replace(tzinfo=self.tz_mrk):
                    print("End of session !")
                    self.ev.set()

                cnt = 0
                while cnt < self.idle_second and not ev.is_set():
                    cnt=cnt+1
                    time.sleep(1)

        self.ev.clear()
        self.schedule_thread = Thread(target=EXEC_LOOP, args=(self.ev, ))
        self.schedule_thread.start()

    def stop(self):
        self.ev.set()
        self.schedule_thread.join()
        self.ev.clear()

# %%
scheduler = Strategy_Scheduler(func=Strategy__STOCK_BY_BBANDS_AND_KD, \
                               trade_time_list= [
                                   dt.time(hour=9,minute=30,second=0),
                                   dt.time(hour=10,minute=0,second=0),
                                   dt.time(hour=11,minute=0,second=0),
                                   dt.time(hour=12,minute=0,second=0),
                                   dt.time(hour=13,minute=0,second=0),
                                   dt.time(hour=14,minute=0,second=0),
                                   dt.time(hour=15,minute=0,second=0),
                                   dt.time(hour=16,minute=0,second=0)],
                               idle_second = 0
                              )

# %%
#scheduler.start(debug=True, end_date_mrk=dt.datetime.strptime('20220808','%Y%m%d'))
scheduler.start(debug=True, end_date_mrk=dt.datetime.strptime('20240314','%Y%m%d'))
# Out:
# Strategy[Strategy__STOCK_BY_BBANDS_AND_KD] Scheduled
# @LocalTime =2022-12-13T22:51:00+08:00
# @ServerTime=2022-12-13T16:51:00+02:00
# @MarketTime=2022-12-13T09:51:00-05:00
# exec_times = 1
# [Strategy__STOCK_BY_BBANDS_AND_KD] Refresh all Stocks ...
# [Strategy__STOCK_BY_BBANDS_AND_KD] Close trade ...
# [close_trade_Strategy__STOCK_HIT_BBANDS_UB]
# [Strategy__STOCK_BY_BBANDS_AND_KD] Generating trade signals ...
# [signal_gen_Strategy__STOCK_HIT_BBANDS_LB]
# 100%|██████████| 1/1 [00:00<00:00, 11.16it/s]
# KD_crs_up_pos
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06     True
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12     True
# 2022-12-13    False
# dtype: bool
# KD_crs_up_2
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01     True
# 2022-12-02     True
# 2022-12-05     True
# 2022-12-06     True
# 2022-12-07     True
# 2022-12-08     True
# 2022-12-09     True
# 2022-12-12     True
# 2022-12-13     True
# dtype: bool
# KD_crs_up_pos1
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos2
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06     True
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12     True
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos_order_id
# Time
# 2022-11-01    NaN
# 2022-11-02    NaN
# 2022-11-03    NaN
# 2022-11-04    NaN
# 2022-11-07    NaN
# 2022-11-08    NaN
# 2022-11-09    NaN
# 2022-11-10    NaN
# 2022-11-11    NaN
# 2022-11-14    NaN
# 2022-11-15    NaN
# 2022-11-16    NaN
# 2022-11-17    NaN
# 2022-11-18    NaN
# 2022-11-21    NaN
# 2022-11-22    2.0
# 2022-11-23    NaN
# 2022-11-25    NaN
# 2022-11-28    NaN
# 2022-11-29    NaN
# 2022-11-30    2.0
# 2022-12-01    NaN
# 2022-12-02    NaN
# 2022-12-05    NaN
# 2022-12-06    2.0
# 2022-12-07    NaN
# 2022-12-08    NaN
# 2022-12-09    NaN
# 2022-12-12    2.0
# 2022-12-13    NaN
# dtype: float64
# KD_crs_up_pos_in_order
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos_d_inc
# Time
# 2022-11-01          NaN
# 2022-11-02          NaN
# 2022-11-03          NaN
# 2022-11-04          NaN
# 2022-11-07          NaN
# 2022-11-08          NaN
# 2022-11-09          NaN
# 2022-11-10          NaN
# 2022-11-11          NaN
# 2022-11-14          NaN
# 2022-11-15          NaN
# 2022-11-16          NaN
# 2022-11-17          NaN
# 2022-11-18          NaN
# 2022-11-21          NaN
# 2022-11-22    19.476330
# 2022-11-23    19.476330
# 2022-11-25    19.476330
# 2022-11-28    19.476330
# 2022-11-29    19.476330
# 2022-11-30    50.857808
# 2022-12-01    50.857808
# 2022-12-02    50.857808
# 2022-12-05    50.857808
# 2022-12-06    53.767753
# 2022-12-07    53.767753
# 2022-12-08    53.767753
# 2022-12-09    53.767753
# 2022-12-12    24.264087
# 2022-12-13    24.264087
# Name: slowd, dtype: float64
# KD_crs_up_pos_d_inc_until
# Time
# 2022-11-01     NaN
# 2022-11-02     NaN
# 2022-11-03     NaN
# 2022-11-04     NaN
# 2022-11-07     NaN
# 2022-11-08     NaN
# 2022-11-09     NaN
# 2022-11-10     NaN
# 2022-11-11     NaN
# 2022-11-14     NaN
# 2022-11-15     NaN
# 2022-11-16     NaN
# 2022-11-17     NaN
# 2022-11-18     NaN
# 2022-11-21     NaN
# 2022-11-22     NaN
# 2022-11-23     NaN
# 2022-11-25     NaN
# 2022-11-28     NaN
# 2022-11-29     NaN
# 2022-11-30    True
# 2022-12-01    True
# 2022-12-02    True
# 2022-12-05    True
# 2022-12-06    True
# 2022-12-07    True
# 2022-12-08    True
# 2022-12-09    True
# 2022-12-12    True
# 2022-12-13    True
# dtype: object
# KD_crs_up_pos_low_not_inc
# Time
# 2022-11-01      NaN
# 2022-11-02      NaN
# 2022-11-03      NaN
# 2022-11-04      NaN
# 2022-11-07      NaN
# 2022-11-08      NaN
# 2022-11-09      NaN
# 2022-11-10      NaN
# 2022-11-11      NaN
# 2022-11-14      NaN
# 2022-11-15      NaN
# 2022-11-16      NaN
# 2022-11-17      NaN
# 2022-11-18      NaN
# 2022-11-21      NaN
# 2022-11-22    13.34
# 2022-11-23    13.34
# 2022-11-25    13.34
# 2022-11-28    13.34
# 2022-11-29    13.34
# 2022-11-30    13.75
# 2022-12-01    13.75
# 2022-12-02    13.75
# 2022-12-05    13.75
# 2022-12-06    13.62
# 2022-12-07    13.62
# 2022-12-08    13.62
# 2022-12-09    13.62
# 2022-12-12    13.35
# 2022-12-13    13.35
# Name: low, dtype: float64
# KD_crs_up_pos_low_not_inc_until
# Time
# 2022-11-01     NaN
# 2022-11-02     NaN
# 2022-11-03     NaN
# 2022-11-04     NaN
# 2022-11-07     NaN
# 2022-11-08     NaN
# 2022-11-09     NaN
# 2022-11-10     NaN
# 2022-11-11     NaN
# 2022-11-14     NaN
# 2022-11-15     NaN
# 2022-11-16     NaN
# 2022-11-17     NaN
# 2022-11-18     NaN
# 2022-11-21     NaN
# 2022-11-22     NaN
# 2022-11-23    True
# 2022-11-25    True
# 2022-11-28    True
# 2022-11-29    True
# 2022-11-30    True
# 2022-12-01    True
# 2022-12-02    True
# 2022-12-05    True
# 2022-12-06    True
# 2022-12-07    True
# 2022-12-08    True
# 2022-12-09    True
# 2022-12-12    True
# 2022-12-13    True
# dtype: object
# price
#              open   high    low  close  volume
# Time
# 2022-11-01  14.43  14.50  14.07  14.10    2476
# 2022-11-02  13.96  14.24  13.55  13.56    4047
# 2022-11-03  13.35  13.84  13.18  13.69    2684
# 2022-11-04  14.21  14.37  13.83  14.07    3726
# 2022-11-07  14.30  14.36  13.83  14.27    1948
# 2022-11-08  14.34  14.42  14.06  14.22    2036
# 2022-11-09  14.09  14.31  13.96  13.96    1991
# 2022-11-10  14.50  14.96  14.34  14.89    2399
# 2022-11-11  15.03  15.04  14.70  14.86    1968
# 2022-11-14  14.75  15.00  14.53  14.66    1987
# 2022-11-15  15.03  15.15  14.50  14.59    2534
# 2022-11-16  14.39  14.39  13.93  14.06    1729
# 2022-11-17  13.81  13.99  13.66  13.90    1432
# 2022-11-18  14.43  14.54  13.86  14.01    1648
# 2022-11-21  13.99  14.24  13.78  13.82    1147
# 2022-11-22  13.64  14.00  13.34  13.95    1357
# 2022-11-23  13.95  14.40  13.86  14.38    1382
# 2022-11-25  14.35  14.67  14.33  14.48     943
# 2022-11-28  14.35  14.41  13.75  13.82    1090
# 2022-11-29  13.88  14.13  13.81  14.11    1173
# 2022-11-30  14.09  14.41  13.87  14.39    1902
# 2022-12-01  14.47  14.54  13.90  13.94    1521
# 2022-12-02  13.80  13.95  13.62  13.95    1289
# 2022-12-05  13.87  14.31  13.82  14.10    1474
# 2022-12-06  14.08  14.31  13.96  14.28    1712
# 2022-12-07  14.11  14.11  13.50  13.52    1974
# 2022-12-08  13.67  13.77  13.35  13.57    1436
# 2022-12-09  13.45  13.63  13.39  13.51    1323
# 2022-12-12  13.44  14.18  13.43  14.18    1261
# 2022-12-13  14.64  14.64  14.58  14.58     229
# KD
#                 slowk      slowd       diff  diff>0  (diff>0).diff  \
# Time
# 2022-11-01        NaN        NaN        NaN       0            NaN
# 2022-11-02        NaN        NaN        NaN       0            0.0
# 2022-11-03        NaN        NaN        NaN       0            0.0
# 2022-11-04        NaN        NaN        NaN       0            0.0
# 2022-11-07        NaN        NaN        NaN       0            0.0
# 2022-11-08        NaN        NaN        NaN       0            0.0
# 2022-11-09        NaN        NaN        NaN       0            0.0
# 2022-11-10        NaN        NaN        NaN       0            0.0
# 2022-11-11        NaN        NaN        NaN       0            0.0
# 2022-11-14        NaN        NaN        NaN       0            0.0
# 2022-11-15        NaN        NaN        NaN       0            0.0
# 2022-11-16        NaN        NaN        NaN       0            0.0
# 2022-11-17  35.035076  57.237672 -22.202595       0            0.0
# 2022-11-18  19.007186  36.743836 -17.736650       0            0.0
# 2022-11-21  16.778523  23.606929  -6.828405       0            0.0
# 2022-11-22  22.643282  19.476330   3.166951       1            1.0
# 2022-11-23  33.966159  24.462655   9.503504       1            0.0
# 2022-11-25  51.381215  35.996885  15.384330       1            0.0
# 2022-11-28  48.987109  44.778161   4.208948       1            0.0
# 2022-11-29  49.132500  49.833608  -0.701108       0           -1.0
# 2022-11-30  54.453814  50.857808   3.596007       1            1.0
# 2022-12-01  60.651629  54.745981   5.905648       1            0.0
# 2022-12-02  56.641604  57.249016  -0.607412       0           -1.0
# 2022-12-05  49.373434  55.555556  -6.182122       0            0.0
# 2022-12-06  55.288221  53.767753   1.520468       1            1.0
# 2022-12-07  40.569801  48.410485  -7.840684       0           -1.0
# 2022-12-08  27.684647  41.180889 -13.496243       0            0.0
# 2022-12-09  11.214058  26.489502 -15.275444       0            0.0
# 2022-12-12  33.893557  24.264087   9.629470       1            1.0
# 2022-12-13  59.514038  34.873885  24.640154       1            0.0
#
#             (diff>0).diff>0
# Time
# 2022-11-01            False
# 2022-11-02            False
# 2022-11-03            False
# 2022-11-04            False
# 2022-11-07            False
# 2022-11-08            False
# 2022-11-09            False
# 2022-11-10            False
# 2022-11-11            False
# 2022-11-14            False
# 2022-11-15            False
# 2022-11-16            False
# 2022-11-17            False
# 2022-11-18            False
# 2022-11-21            False
# 2022-11-22             True
# 2022-11-23            False
# 2022-11-25            False
# 2022-11-28            False
# 2022-11-29            False
# 2022-11-30             True
# 2022-12-01            False
# 2022-12-02            False
# 2022-12-05            False
# 2022-12-06             True
# 2022-12-07            False
# 2022-12-08            False
# 2022-12-09            False
# 2022-12-12             True
# 2022-12-13            False
# BB
#             upperband  middleband  lowerband
# Time
# 2022-11-01        NaN         NaN        NaN
# 2022-11-02        NaN         NaN        NaN
# 2022-11-03        NaN         NaN        NaN
# 2022-11-04        NaN         NaN        NaN
# 2022-11-07        NaN         NaN        NaN
# 2022-11-08        NaN         NaN        NaN
# 2022-11-09        NaN         NaN        NaN
# 2022-11-10        NaN         NaN        NaN
# 2022-11-11        NaN         NaN        NaN
# 2022-11-14        NaN         NaN        NaN
# 2022-11-15        NaN         NaN        NaN
# 2022-11-16        NaN         NaN        NaN
# 2022-11-17        NaN         NaN        NaN
# 2022-11-18        NaN         NaN        NaN
# 2022-11-21        NaN         NaN        NaN
# 2022-11-22        NaN         NaN        NaN
# 2022-11-23        NaN         NaN        NaN
# 2022-11-25        NaN         NaN        NaN
# 2022-11-28        NaN         NaN        NaN
# 2022-11-29        NaN         NaN        NaN
# 2022-11-30  14.930522   14.180476  13.430431
# 2022-12-01  14.929888   14.172857  13.415826
# 2022-12-02  14.900745   14.191429  13.482112
# 2022-12-05  14.882074   14.210952  13.539831
# 2022-12-06  14.889377   14.220952  13.552527
# 2022-12-07  14.922695   14.185238  13.447782
# 2022-12-08  14.940957   14.154286  13.367614
# 2022-12-09  14.967166   14.132857  13.298548
# 2022-12-12  14.854767   14.099048  13.343328
# 2022-12-13  14.790912   14.085714  13.380516
# [signal_gen_Strategy__STOCK_HIT_BBANDS_LB]
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# Time
# 2022-11-01         NaN
# 2022-11-02         NaN
# 2022-11-03         NaN
# 2022-11-04         NaN
# 2022-11-07         NaN
# 2022-11-08         NaN
# 2022-11-09         NaN
# 2022-11-10         NaN
# 2022-11-11         NaN
# 2022-11-14         NaN
# 2022-11-15         NaN
# 2022-11-16         NaN
# 2022-11-17         NaN
# 2022-11-18         NaN
# 2022-11-21         NaN
# 2022-11-22         NaN
# 2022-11-23         NaN
# 2022-11-25         NaN
# 2022-11-28         NaN
# 2022-11-29         NaN
# 2022-11-30    0.586057
# 2022-12-01    0.639569
# 2022-12-02    0.194396
# 2022-12-05    0.417464
# 2022-12-06    0.609601
# 2022-12-07    0.070809
# 2022-12-08   -0.022391
# 2022-12-09    0.109614
# 2022-12-12    0.114688
# 2022-12-13    1.700918
# dtype: float64
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# RR_ratio =  (14.79091-14.65000)/(14.65000-13.35+0.07000) =  0.10285556955802963
# KD_up_crs_D_lte20_win10 : False
# KD_crs3_win10 : False
# KD_diff_pos : True
# KD_diff3 : True
# KD_diff_inc : True
# KD_diff_inc_win2 : True
# KD_diff_lt3_win4_shift1 : False
# KD_K_slope_pos : True
# KD_D_slope_pos : True
# KD_D_slope_pos3 : False
# KD_D_slope_neg_win4_shift1 : True
# KD_D_lt20_win4_shift1 : False
# KD_D_inc6_win2 : True
# KD_K_inc6 : True
# KD_K_slope_gte5 : True
# KD_K_slope_gte10 : True
# KD_bull_divergence : False
# KD_saturate_gt6 : False
# BB_nearLB_win : True
# BB_nearLB : False
# BB_RiskReward : False
# BB_nearLB_win13 : True
# close_min : True
# close_gt_close1 : True
# close_gt_high1 : True
# close_gt_close_open_avg1 : True
# close_gt_high_low_avg1 : True
# up_candle1 : True
# up_candle : False
# now_srv_gt1500 : True
# [Strategy__STOCK_BY_BBANDS_AND_KD] Remove opend position from selected stocks ...
# [RemoveOpenPositionEver:ALL_SRC_SYMBOL] => []
# [RemoveOpenPositionEver:REDUCED_SYMBOL] => []
# [Strategy__STOCK_BY_BBANDS_AND_KD] open trade ...
# Tick Finished @ServerTime 2022-12-13T16:51:00+02:00
# Tick Finished @ServerTime 2022-12-13T16:51:00+02:00
# Tick Finished @ServerTime 2022-12-13T16:51:00+02:00
#
# Strategy[Strategy__STOCK_BY_BBANDS_AND_KD] Scheduled
# @LocalTime =2022-12-13T23:11:00+08:00
# @ServerTime=2022-12-13T17:11:00+02:00
# @MarketTime=2022-12-13T10:11:00-05:00
# exec_times = 2
# [Strategy__STOCK_BY_BBANDS_AND_KD] Refresh all Stocks ...
# [Strategy__STOCK_BY_BBANDS_AND_KD] Close trade ...
# [close_trade_Strategy__STOCK_HIT_BBANDS_UB]
# [Strategy__STOCK_BY_BBANDS_AND_KD] Generating trade signals ...
# [signal_gen_Strategy__STOCK_HIT_BBANDS_LB]
# 100%|██████████| 1/1 [00:00<00:00, 25.31it/s]
# KD_crs_up_pos
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06     True
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12     True
# 2022-12-13    False
# dtype: bool
# KD_crs_up_2
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01     True
# 2022-12-02     True
# 2022-12-05     True
# 2022-12-06     True
# 2022-12-07     True
# 2022-12-08     True
# 2022-12-09     True
# 2022-12-12     True
# 2022-12-13     True
# dtype: bool
# KD_crs_up_pos1
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos2
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06     True
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12     True
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos_order_id
# Time
# 2022-11-01    NaN
# 2022-11-02    NaN
# 2022-11-03    NaN
# 2022-11-04    NaN
# 2022-11-07    NaN
# 2022-11-08    NaN
# 2022-11-09    NaN
# 2022-11-10    NaN
# 2022-11-11    NaN
# 2022-11-14    NaN
# 2022-11-15    NaN
# 2022-11-16    NaN
# 2022-11-17    NaN
# 2022-11-18    NaN
# 2022-11-21    NaN
# 2022-11-22    2.0
# 2022-11-23    NaN
# 2022-11-25    NaN
# 2022-11-28    NaN
# 2022-11-29    NaN
# 2022-11-30    2.0
# 2022-12-01    NaN
# 2022-12-02    NaN
# 2022-12-05    NaN
# 2022-12-06    2.0
# 2022-12-07    NaN
# 2022-12-08    NaN
# 2022-12-09    NaN
# 2022-12-12    2.0
# 2022-12-13    NaN
# dtype: float64
# KD_crs_up_pos_in_order
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos_d_inc
# Time
# 2022-11-01          NaN
# 2022-11-02          NaN
# 2022-11-03          NaN
# 2022-11-04          NaN
# 2022-11-07          NaN
# 2022-11-08          NaN
# 2022-11-09          NaN
# 2022-11-10          NaN
# 2022-11-11          NaN
# 2022-11-14          NaN
# 2022-11-15          NaN
# 2022-11-16          NaN
# 2022-11-17          NaN
# 2022-11-18          NaN
# 2022-11-21          NaN
# 2022-11-22    19.476330
# 2022-11-23    19.476330
# 2022-11-25    19.476330
# 2022-11-28    19.476330
# 2022-11-29    19.476330
# 2022-11-30    50.857808
# 2022-12-01    50.857808
# 2022-12-02    50.857808
# 2022-12-05    50.857808
# 2022-12-06    53.767753
# 2022-12-07    53.767753
# 2022-12-08    53.767753
# 2022-12-09    53.767753
# 2022-12-12    24.264087
# 2022-12-13    24.264087
# Name: slowd, dtype: float64
# KD_crs_up_pos_d_inc_until
# Time
# 2022-11-01     NaN
# 2022-11-02     NaN
# 2022-11-03     NaN
# 2022-11-04     NaN
# 2022-11-07     NaN
# 2022-11-08     NaN
# 2022-11-09     NaN
# 2022-11-10     NaN
# 2022-11-11     NaN
# 2022-11-14     NaN
# 2022-11-15     NaN
# 2022-11-16     NaN
# 2022-11-17     NaN
# 2022-11-18     NaN
# 2022-11-21     NaN
# 2022-11-22     NaN
# 2022-11-23     NaN
# 2022-11-25     NaN
# 2022-11-28     NaN
# 2022-11-29     NaN
# 2022-11-30    True
# 2022-12-01    True
# 2022-12-02    True
# 2022-12-05    True
# 2022-12-06    True
# 2022-12-07    True
# 2022-12-08    True
# 2022-12-09    True
# 2022-12-12    True
# 2022-12-13    True
# dtype: object
# KD_crs_up_pos_low_not_inc
# Time
# 2022-11-01      NaN
# 2022-11-02      NaN
# 2022-11-03      NaN
# 2022-11-04      NaN
# 2022-11-07      NaN
# 2022-11-08      NaN
# 2022-11-09      NaN
# 2022-11-10      NaN
# 2022-11-11      NaN
# 2022-11-14      NaN
# 2022-11-15      NaN
# 2022-11-16      NaN
# 2022-11-17      NaN
# 2022-11-18      NaN
# 2022-11-21      NaN
# 2022-11-22    13.34
# 2022-11-23    13.34
# 2022-11-25    13.34
# 2022-11-28    13.34
# 2022-11-29    13.34
# 2022-11-30    13.75
# 2022-12-01    13.75
# 2022-12-02    13.75
# 2022-12-05    13.75
# 2022-12-06    13.62
# 2022-12-07    13.62
# 2022-12-08    13.62
# 2022-12-09    13.62
# 2022-12-12    13.35
# 2022-12-13    13.35
# Name: low, dtype: float64
# KD_crs_up_pos_low_not_inc_until
# Time
# 2022-11-01     NaN
# 2022-11-02     NaN
# 2022-11-03     NaN
# 2022-11-04     NaN
# 2022-11-07     NaN
# 2022-11-08     NaN
# 2022-11-09     NaN
# 2022-11-10     NaN
# 2022-11-11     NaN
# 2022-11-14     NaN
# 2022-11-15     NaN
# 2022-11-16     NaN
# 2022-11-17     NaN
# 2022-11-18     NaN
# 2022-11-21     NaN
# 2022-11-22     NaN
# 2022-11-23    True
# 2022-11-25    True
# 2022-11-28    True
# 2022-11-29    True
# 2022-11-30    True
# 2022-12-01    True
# 2022-12-02    True
# 2022-12-05    True
# 2022-12-06    True
# 2022-12-07    True
# 2022-12-08    True
# 2022-12-09    True
# 2022-12-12    True
# 2022-12-13    True
# dtype: object
# price
#              open   high    low  close  volume
# Time
# 2022-11-01  14.43  14.50  14.07  14.10    2476
# 2022-11-02  13.96  14.24  13.55  13.56    4047
# 2022-11-03  13.35  13.84  13.18  13.69    2684
# 2022-11-04  14.21  14.37  13.83  14.07    3726
# 2022-11-07  14.30  14.36  13.83  14.27    1948
# 2022-11-08  14.34  14.42  14.06  14.22    2036
# 2022-11-09  14.09  14.31  13.96  13.96    1991
# 2022-11-10  14.50  14.96  14.34  14.89    2399
# 2022-11-11  15.03  15.04  14.70  14.86    1968
# 2022-11-14  14.75  15.00  14.53  14.66    1987
# 2022-11-15  15.03  15.15  14.50  14.59    2534
# 2022-11-16  14.39  14.39  13.93  14.06    1729
# 2022-11-17  13.81  13.99  13.66  13.90    1432
# 2022-11-18  14.43  14.54  13.86  14.01    1648
# 2022-11-21  13.99  14.24  13.78  13.82    1147
# 2022-11-22  13.64  14.00  13.34  13.95    1357
# 2022-11-23  13.95  14.40  13.86  14.38    1382
# 2022-11-25  14.35  14.67  14.33  14.48     943
# 2022-11-28  14.35  14.41  13.75  13.82    1090
# 2022-11-29  13.88  14.13  13.81  14.11    1173
# 2022-11-30  14.09  14.41  13.87  14.39    1902
# 2022-12-01  14.47  14.54  13.90  13.94    1521
# 2022-12-02  13.80  13.95  13.62  13.95    1289
# 2022-12-05  13.87  14.31  13.82  14.10    1474
# 2022-12-06  14.08  14.31  13.96  14.28    1712
# 2022-12-07  14.11  14.11  13.50  13.52    1974
# 2022-12-08  13.67  13.77  13.35  13.57    1436
# 2022-12-09  13.45  13.63  13.39  13.51    1323
# 2022-12-12  13.44  14.18  13.43  14.18    1261
# 2022-12-13  14.64  14.64  14.45  14.45     458
# KD
#                 slowk      slowd       diff  diff>0  (diff>0).diff  \
# Time
# 2022-11-01        NaN        NaN        NaN       0            NaN
# 2022-11-02        NaN        NaN        NaN       0            0.0
# 2022-11-03        NaN        NaN        NaN       0            0.0
# 2022-11-04        NaN        NaN        NaN       0            0.0
# 2022-11-07        NaN        NaN        NaN       0            0.0
# 2022-11-08        NaN        NaN        NaN       0            0.0
# 2022-11-09        NaN        NaN        NaN       0            0.0
# 2022-11-10        NaN        NaN        NaN       0            0.0
# 2022-11-11        NaN        NaN        NaN       0            0.0
# 2022-11-14        NaN        NaN        NaN       0            0.0
# 2022-11-15        NaN        NaN        NaN       0            0.0
# 2022-11-16        NaN        NaN        NaN       0            0.0
# 2022-11-17  35.035076  57.237672 -22.202595       0            0.0
# 2022-11-18  19.007186  36.743836 -17.736650       0            0.0
# 2022-11-21  16.778523  23.606929  -6.828405       0            0.0
# 2022-11-22  22.643282  19.476330   3.166951       1            1.0
# 2022-11-23  33.966159  24.462655   9.503504       1            0.0
# 2022-11-25  51.381215  35.996885  15.384330       1            0.0
# 2022-11-28  48.987109  44.778161   4.208948       1            0.0
# 2022-11-29  49.132500  49.833608  -0.701108       0           -1.0
# 2022-11-30  54.453814  50.857808   3.596007       1            1.0
# 2022-12-01  60.651629  54.745981   5.905648       1            0.0
# 2022-12-02  56.641604  57.249016  -0.607412       0           -1.0
# 2022-12-05  49.373434  55.555556  -6.182122       0            0.0
# 2022-12-06  55.288221  53.767753   1.520468       1            1.0
# 2022-12-07  40.569801  48.410485  -7.840684       0           -1.0
# 2022-12-08  27.684647  41.180889 -13.496243       0            0.0
# 2022-12-09  11.214058  26.489502 -15.275444       0            0.0
# 2022-12-12  33.893557  24.264087   9.629470       1            1.0
# 2022-12-13  56.154865  33.754160  22.400705       1            0.0
#
#             (diff>0).diff>0
# Time
# 2022-11-01            False
# 2022-11-02            False
# 2022-11-03            False
# 2022-11-04            False
# 2022-11-07            False
# 2022-11-08            False
# 2022-11-09            False
# 2022-11-10            False
# 2022-11-11            False
# 2022-11-14            False
# 2022-11-15            False
# 2022-11-16            False
# 2022-11-17            False
# 2022-11-18            False
# 2022-11-21            False
# 2022-11-22             True
# 2022-11-23            False
# 2022-11-25            False
# 2022-11-28            False
# 2022-11-29            False
# 2022-11-30             True
# 2022-12-01            False
# 2022-12-02            False
# 2022-12-05            False
# 2022-12-06             True
# 2022-12-07            False
# 2022-12-08            False
# 2022-12-09            False
# 2022-12-12             True
# 2022-12-13            False
# BB
#             upperband  middleband  lowerband
# Time
# 2022-11-01        NaN         NaN        NaN
# 2022-11-02        NaN         NaN        NaN
# 2022-11-03        NaN         NaN        NaN
# 2022-11-04        NaN         NaN        NaN
# 2022-11-07        NaN         NaN        NaN
# 2022-11-08        NaN         NaN        NaN
# 2022-11-09        NaN         NaN        NaN
# 2022-11-10        NaN         NaN        NaN
# 2022-11-11        NaN         NaN        NaN
# 2022-11-14        NaN         NaN        NaN
# 2022-11-15        NaN         NaN        NaN
# 2022-11-16        NaN         NaN        NaN
# 2022-11-17        NaN         NaN        NaN
# 2022-11-18        NaN         NaN        NaN
# 2022-11-21        NaN         NaN        NaN
# 2022-11-22        NaN         NaN        NaN
# 2022-11-23        NaN         NaN        NaN
# 2022-11-25        NaN         NaN        NaN
# 2022-11-28        NaN         NaN        NaN
# 2022-11-29        NaN         NaN        NaN
# 2022-11-30  14.930522   14.180476  13.430431
# 2022-12-01  14.929888   14.172857  13.415826
# 2022-12-02  14.900745   14.191429  13.482112
# 2022-12-05  14.882074   14.210952  13.539831
# 2022-12-06  14.889377   14.220952  13.552527
# 2022-12-07  14.922695   14.185238  13.447782
# 2022-12-08  14.940957   14.154286  13.367614
# 2022-12-09  14.967166   14.132857  13.298548
# 2022-12-12  14.854767   14.099048  13.343328
# 2022-12-13  14.767780   14.079524  13.391268
# [signal_gen_Strategy__STOCK_HIT_BBANDS_LB]
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# Time
# 2022-11-01         NaN
# 2022-11-02         NaN
# 2022-11-03         NaN
# 2022-11-04         NaN
# 2022-11-07         NaN
# 2022-11-08         NaN
# 2022-11-09         NaN
# 2022-11-10         NaN
# 2022-11-11         NaN
# 2022-11-14         NaN
# 2022-11-15         NaN
# 2022-11-16         NaN
# 2022-11-17         NaN
# 2022-11-18         NaN
# 2022-11-21         NaN
# 2022-11-22         NaN
# 2022-11-23         NaN
# 2022-11-25         NaN
# 2022-11-28         NaN
# 2022-11-29         NaN
# 2022-11-30    0.586057
# 2022-12-01    0.639569
# 2022-12-02    0.194396
# 2022-12-05    0.417464
# 2022-12-06    0.609601
# 2022-12-07    0.070809
# 2022-12-08   -0.022391
# 2022-12-09    0.109614
# 2022-12-12    0.114688
# 2022-12-13    1.538283
# dtype: float64
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# RR_ratio =  (14.76778-14.52000)/(14.52000-13.35+0.07000) =  0.19982223865850626
# KD_up_crs_D_lte20_win10 : False
# KD_crs3_win10 : False
# KD_diff_pos : True
# KD_diff3 : True
# KD_diff_inc : True
# KD_diff_inc_win2 : True
# KD_diff_lt3_win4_shift1 : False
# KD_K_slope_pos : True
# KD_D_slope_pos : True
# KD_D_slope_pos3 : False
# KD_D_slope_neg_win4_shift1 : True
# KD_D_lt20_win4_shift1 : False
# KD_D_inc6_win2 : True
# KD_K_inc6 : True
# KD_K_slope_gte5 : True
# KD_K_slope_gte10 : True
# KD_bull_divergence : False
# KD_saturate_gt6 : False
# BB_nearLB_win : True
# BB_nearLB : False
# BB_RiskReward : False
# BB_nearLB_win13 : True
# close_min : True
# close_gt_close1 : True
# close_gt_high1 : True
# close_gt_close_open_avg1 : True
# close_gt_high_low_avg1 : True
# up_candle1 : True
# up_candle : False
# now_srv_gt1500 : True
# [Strategy__STOCK_BY_BBANDS_AND_KD] Remove opend position from selected stocks ...
# [RemoveOpenPositionEver:ALL_SRC_SYMBOL] => []
# [RemoveOpenPositionEver:REDUCED_SYMBOL] => []
# [Strategy__STOCK_BY_BBANDS_AND_KD] open trade ...
# Tick Finished @ServerTime 2022-12-13T17:11:00+02:00
# Tick Finished @ServerTime 2022-12-13T17:31:00+02:00
# Tick Finished @ServerTime 2022-12-13T17:31:00+02:00
# Tick Finished @ServerTime 2022-12-13T17:31:00+02:00
# Tick Finished @ServerTime 2022-12-13T17:51:00+02:00
# Tick Finished @ServerTime 2022-12-13T17:51:00+02:00
# Tick Finished @ServerTime 2022-12-13T17:51:00+02:00
#
# Strategy[Strategy__STOCK_BY_BBANDS_AND_KD] Scheduled
# @LocalTime =2022-12-14T00:11:00+08:00
# @ServerTime=2022-12-13T18:11:00+02:00
# @MarketTime=2022-12-13T11:11:00-05:00
# exec_times = 3
# [Strategy__STOCK_BY_BBANDS_AND_KD] Refresh all Stocks ...
# [Strategy__STOCK_BY_BBANDS_AND_KD] Close trade ...
# [close_trade_Strategy__STOCK_HIT_BBANDS_UB]
# [Strategy__STOCK_BY_BBANDS_AND_KD] Generating trade signals ...
# [signal_gen_Strategy__STOCK_HIT_BBANDS_LB]
#   0%|          | 0/1 [00:00<?, ?it/s]
# KD_crs_up_pos
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06     True
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12     True
# 2022-12-13    False
# dtype: bool
# KD_crs_up_2
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01     True
# 2022-12-02     True
# 2022-12-05     True
# 2022-12-06     True
# 2022-12-07     True
# 2022-12-08     True
# 2022-12-09     True
# 2022-12-12     True
# 2022-12-13     True
# dtype: bool
# KD_crs_up_pos1
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos2
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30     True
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06     True
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12     True
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos_order_id
# Time
# 2022-11-01    NaN
# 2022-11-02    NaN
# 2022-11-03    NaN
# 2022-11-04    NaN
# 2022-11-07    NaN
# 2022-11-08    NaN
# 2022-11-09    NaN
# 2022-11-10    NaN
# 2022-11-11    NaN
# 2022-11-14    NaN
# 2022-11-15    NaN
# 2022-11-16    NaN
# 2022-11-17    NaN
# 2022-11-18    NaN
# 2022-11-21    NaN
# 2022-11-22    2.0
# 2022-11-23    NaN
# 2022-11-25    NaN
# 2022-11-28    NaN
# 2022-11-29    NaN
# 2022-11-30    2.0
# 2022-12-01    NaN
# 2022-12-02    NaN
# 2022-12-05    NaN
# 2022-12-06    2.0
# 2022-12-07    NaN
# 2022-12-08    NaN
# 2022-12-09    NaN
# 2022-12-12    2.0
# 2022-12-13    NaN
# dtype: float64
# KD_crs_up_pos_in_order
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# KD_crs_up_pos_d_inc
# Time
# 2022-11-01          NaN
# 2022-11-02          NaN
# 2022-11-03          NaN
# 2022-11-04          NaN
# 2022-11-07          NaN
# 2022-11-08          NaN
# 2022-11-09          NaN
# 2022-11-10          NaN
# 2022-11-11          NaN
# 2022-11-14          NaN
# 2022-11-15          NaN
# 2022-11-16          NaN
# 2022-11-17          NaN
# 2022-11-18          NaN
# 2022-11-21          NaN
# 2022-11-22    19.476330
# 2022-11-23    19.476330
# 2022-11-25    19.476330
# 2022-11-28    19.476330
# 2022-11-29    19.476330
# 2022-11-30    50.857808
# 2022-12-01    50.857808
# 2022-12-02    50.857808
# 2022-12-05    50.857808
# 2022-12-06    53.767753
# 2022-12-07    53.767753
# 2022-12-08    53.767753
# 2022-12-09    53.767753
# 2022-12-12    24.264087
# 2022-12-13    24.264087
# Name: slowd, dtype: float64
# KD_crs_up_pos_d_inc_until
# Time
# 2022-11-01     NaN
# 2022-11-02     NaN
# 2022-11-03     NaN
# 2022-11-04     NaN
# 2022-11-07     NaN
# 2022-11-08     NaN
# 2022-11-09     NaN
# 2022-11-10     NaN
# 2022-11-11     NaN
# 2022-11-14     NaN
# 2022-11-15     NaN
# 2022-11-16     NaN
# 2022-11-17     NaN
# 2022-11-18     NaN
# 2022-11-21     NaN
# 2022-11-22     NaN
# 2022-11-23     NaN
# 2022-11-25     NaN
# 2022-11-28     NaN
# 2022-11-29     NaN
# 2022-11-30    True
# 2022-12-01    True
# 2022-12-02    True
# 2022-12-05    True
# 2022-12-06    True
# 2022-12-07    True
# 2022-12-08    True
# 2022-12-09    True
# 2022-12-12    True
# 2022-12-13    True
# dtype: object
# KD_crs_up_pos_low_not_inc
# Time
# 2022-11-01      NaN
# 2022-11-02      NaN
# 2022-11-03      NaN
# 2022-11-04      NaN
# 2022-11-07      NaN
# 2022-11-08      NaN
# 2022-11-09      NaN
# 2022-11-10      NaN
# 2022-11-11      NaN
# 2022-11-14      NaN
# 2022-11-15      NaN
# 2022-11-16      NaN
# 2022-11-17      NaN
# 2022-11-18      NaN
# 2022-11-21      NaN
# 2022-11-22    13.34
# 2022-11-23    13.34
# 2022-11-25    13.34
# 2022-11-28    13.34
# 2022-11-29    13.34
# 2022-11-30    13.75
# 2022-12-01    13.75
# 2022-12-02    13.75
# 2022-12-05    13.75
# 2022-12-06    13.62
# 2022-12-07    13.62
# 2022-12-08    13.62
# 2022-12-09    13.62
# 2022-12-12    13.35
# 2022-12-13    13.35
# Name: low, dtype: float64
# KD_crs_up_pos_low_not_inc_until
# Time
# 2022-11-01     NaN
# 2022-11-02     NaN
# 2022-11-03     NaN
# 2022-11-04     NaN
# 2022-11-07     NaN
# 2022-11-08     NaN
# 2022-11-09     NaN
# 2022-11-10     NaN
# 2022-11-11     NaN
# 2022-11-14     NaN
# 2022-11-15     NaN
# 2022-11-16     NaN
# 2022-11-17     NaN
# 2022-11-18     NaN
# 2022-11-21     NaN
# 2022-11-22     NaN
# 2022-11-23    True
# 2022-11-25    True
# 2022-11-28    True
# 2022-11-29    True
# 2022-11-30    True
# 2022-12-01    True
# 2022-12-02    True
# 2022-12-05    True
# 2022-12-06    True
# 2022-12-07    True
# 2022-12-08    True
# 2022-12-09    True
# 2022-12-12    True
# 2022-12-13    True
# dtype: object
# price
#              open   high    low  close  volume
# Time
# 2022-11-01  14.43  14.50  14.07  14.10    2476
# 2022-11-02  13.96  14.24  13.55  13.56    4047
# 2022-11-03  13.35  13.84  13.18  13.69    2684
# 2022-11-04  14.21  14.37  13.83  14.07    3726
# 2022-11-07  14.30  14.36  13.83  14.27    1948
# 2022-11-08  14.34  14.42  14.06  14.22    2036
# 2022-11-09  14.09  14.31  13.96  13.96    1991
# 2022-11-10  14.50  14.96  14.34  14.89    2399
# 2022-11-11  15.03  15.04  14.70  14.86    1968
# 2022-11-14  14.75  15.00  14.53  14.66    1987
# 2022-11-15  15.03  15.15  14.50  14.59    2534
# 2022-11-16  14.39  14.39  13.93  14.06    1729
# 2022-11-17  13.81  13.99  13.66  13.90    1432
# 2022-11-18  14.43  14.54  13.86  14.01    1648
# 2022-11-21  13.99  14.24  13.78  13.82    1147
# 2022-11-22  13.64  14.00  13.34  13.95    1357
# 2022-11-23  13.95  14.40  13.86  14.38    1382
# 2022-11-25  14.35  14.67  14.33  14.48     943
# 2022-11-28  14.35  14.41  13.75  13.82    1090
# 2022-11-29  13.88  14.13  13.81  14.11    1173
# 2022-11-30  14.09  14.41  13.87  14.39    1902
# 2022-12-01  14.47  14.54  13.90  13.94    1521
# 2022-12-02  13.80  13.95  13.62  13.95    1289
# 2022-12-05  13.87  14.31  13.82  14.10    1474
# 2022-12-06  14.08  14.31  13.96  14.28    1712
# 2022-12-07  14.11  14.11  13.50  13.52    1974
# 2022-12-08  13.67  13.77  13.35  13.57    1436
# 2022-12-09  13.45  13.63  13.39  13.51    1323
# 2022-12-12  13.44  14.18  13.43  14.18    1261
# 2022-12-13  14.64  14.71  14.19  14.32    1143
# KD
#                 slowk      slowd       diff  diff>0  (diff>0).diff  \
# Time
# 2022-11-01        NaN        NaN        NaN       0            NaN
# 2022-11-02        NaN        NaN        NaN       0            0.0
# 2022-11-03        NaN        NaN        NaN       0            0.0
# 2022-11-04        NaN        NaN        NaN       0            0.0
# 2022-11-07        NaN        NaN        NaN       0            0.0
# 2022-11-08        NaN        NaN        NaN       0            0.0
# 2022-11-09        NaN        NaN        NaN       0            0.0
# 2022-11-10        NaN        NaN        NaN       0            0.0
# 2022-11-11        NaN        NaN        NaN       0            0.0
# 2022-11-14        NaN        NaN        NaN       0            0.0
# 2022-11-15        NaN        NaN        NaN       0            0.0
# 2022-11-16        NaN        NaN        NaN       0            0.0
# 2022-11-17  35.035076  57.237672 -22.202595       0            0.0
# 2022-11-18  19.007186  36.743836 -17.736650       0            0.0
# 2022-11-21  16.778523  23.606929  -6.828405       0            0.0
# 2022-11-22  22.643282  19.476330   3.166951       1            1.0
# 2022-11-23  33.966159  24.462655   9.503504       1            0.0
# 2022-11-25  51.381215  35.996885  15.384330       1            0.0
# 2022-11-28  48.987109  44.778161   4.208948       1            0.0
# 2022-11-29  49.132500  49.833608  -0.701108       0           -1.0
# 2022-11-30  54.453814  50.857808   3.596007       1            1.0
# 2022-12-01  60.651629  54.745981   5.905648       1            0.0
# 2022-12-02  56.641604  57.249016  -0.607412       0           -1.0
# 2022-12-05  49.373434  55.555556  -6.182122       0            0.0
# 2022-12-06  55.288221  53.767753   1.520468       1            1.0
# 2022-12-07  40.569801  48.410485  -7.840684       0           -1.0
# 2022-12-08  27.684647  41.180889 -13.496243       0            0.0
# 2022-12-09  11.214058  26.489502 -15.275444       0            0.0
# 2022-12-12  33.893557  24.264087   9.629470       1            1.0
# 2022-12-13  51.505602  32.204406  19.301196       1            0.0
#
#             (diff>0).diff>0
# Time
# 2022-11-01            False
# 2022-11-02            False
# 2022-11-03            False
# 2022-11-04            False
# 2022-11-07            False
# 2022-11-08            False
# 2022-11-09            False
# 2022-11-10            False
# 2022-11-11            False
# 2022-11-14            False
# 2022-11-15            False
# 2022-11-16            False
# 2022-11-17            False
# 2022-11-18            False
# 2022-11-21            False
# 2022-11-22             True
# 2022-11-23            False
# 2022-11-25            False
# 2022-11-28            False
# 2022-11-29            False
# 2022-11-30             True
# 2022-12-01            False
# 2022-12-02            False
# 2022-12-05            False
# 2022-12-06             True
# 2022-12-07            False
# 2022-12-08            False
# 2022-12-09            False
# 2022-12-12             True
# 2022-12-13            False
# BB
#             upperband  middleband  lowerband
# Time
# 2022-11-01        NaN         NaN        NaN
# 2022-11-02        NaN         NaN        NaN
# 2022-11-03        NaN         NaN        NaN
# 2022-11-04        NaN         NaN        NaN
# 2022-11-07        NaN         NaN        NaN
# 2022-11-08        NaN         NaN        NaN
# 2022-11-09        NaN         NaN        NaN
# 2022-11-10        NaN         NaN        NaN
# 2022-11-11        NaN         NaN        NaN
# 2022-11-14        NaN         NaN        NaN
# 2022-11-15        NaN         NaN        NaN
# 2022-11-16        NaN         NaN        NaN
# 2022-11-17        NaN         NaN        NaN
# 2022-11-18        NaN         NaN        NaN
# 2022-11-21        NaN         NaN        NaN
# 2022-11-22        NaN         NaN        NaN
# 2022-11-23        NaN         NaN        NaN
# 2022-11-25        NaN         NaN        NaN
# 2022-11-28        NaN         NaN        NaN
# 2022-11-29        NaN         NaN        NaN
# 2022-11-30  14.930522   14.180476  13.430431
# 2022-12-01  14.929888   14.172857  13.415826
# 2022-12-02  14.900745   14.191429  13.482112
# 2022-12-05  14.882074   14.210952  13.539831
# 2022-12-06  14.889377   14.220952  13.552527
# 2022-12-07  14.922695   14.185238  13.447782
# 2022-12-08  14.940957   14.154286  13.367614
# 2022-12-09  14.967166   14.132857  13.298548
# 2022-12-12  14.854767   14.099048  13.343328
# 2022-12-13  14.749239   14.073333  13.397428
# [signal_gen_Strategy__STOCK_HIT_BBANDS_LB]
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# dtype: bool
# Time
# 2022-11-01    False
# 2022-11-02    False
# 2022-11-03    False
# 2022-11-04    False
# 2022-11-07    False
# 2022-11-08    False
# 2022-11-09    False
# 2022-11-10    False
# 2022-11-11    False
# 2022-11-14    False
# 2022-11-15    False
# 2022-11-16    False
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22     True
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# ...
# 2022-12-19     True
# 2022-12-20     True
# 2022-12-21     True
# 2022-12-22     True
# 2022-12-23     True
# 2022-12-27     True
# 2022-12-28     True
# 2022-12-29     True
# 2022-12-30     True
# dtype: bool
# KD_crs_up_pos1
# Time
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# 2022-12-14    False
# 2022-12-15    False
# 2022-12-16    False
# 2022-12-19    False
# 2022-12-20    False
# 2022-12-21     True
# 2022-12-22    False
# 2022-12-23    False
# 2022-12-27    False
# 2022-12-28    False
# 2022-12-29    False
# 2022-12-30    False
# dtype: bool
# KD_crs_up_pos2
# Time
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06     True
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12     True
# 2022-12-13    False
# 2022-12-14    False
# 2022-12-15    False
# 2022-12-16    False
# 2022-12-19    False
# 2022-12-20    False
# 2022-12-21    False
# 2022-12-22    False
# 2022-12-23    False
# 2022-12-27    False
# 2022-12-28    False
# 2022-12-29     True
# 2022-12-30    False
# dtype: bool
# KD_crs_up_pos_order_id
# Time
# 2022-11-17    NaN
# 2022-11-18    NaN
# 2022-11-21    NaN
# 2022-11-22    NaN
# 2022-11-23    NaN
# 2022-11-25    NaN
# 2022-11-28    NaN
# 2022-11-29    NaN
# 2022-11-30    NaN
# 2022-12-01    NaN
# 2022-12-02    NaN
# 2022-12-05    NaN
# 2022-12-06    2.0
# 2022-12-07    NaN
# 2022-12-08    NaN
# 2022-12-09    NaN
# 2022-12-12    2.0
# 2022-12-13    NaN
# 2022-12-14    NaN
# 2022-12-15    NaN
# 2022-12-16    NaN
# 2022-12-19    NaN
# 2022-12-20    NaN
# 2022-12-21    1.0
# 2022-12-22    NaN
# 2022-12-23    NaN
# 2022-12-27    NaN
# 2022-12-28    NaN
# 2022-12-29    2.0
# 2022-12-30    NaN
# dtype: float64
# KD_crs_up_pos_in_order
# Time
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# 2022-12-14    False
# 2022-12-15    False
# 2022-12-16    False
# 2022-12-19    False
# 2022-12-20    False
# 2022-12-21    False
# 2022-12-22    False
# 2022-12-23    False
# 2022-12-27    False
# 2022-12-28    False
# 2022-12-29     True
# 2022-12-30     True
# dtype: bool
# KD_crs_up_pos_d_inc
# Time
# 2022-11-17          NaN
# 2022-11-18          NaN
# 2022-11-21          NaN
# 2022-11-22          NaN
# 2022-11-23          NaN
# 2022-11-25          NaN
# 2022-11-28          NaN
# 2022-11-29          NaN
# 2022-11-30          NaN
# 2022-12-01          NaN
# 2022-12-02          NaN
# 2022-12-05          NaN
# 2022-12-06    53.767753
# 2022-12-07    53.767753
# 2022-12-08    53.767753
# 2022-12-09    53.767753
# 2022-12-12    24.264087
# 2022-12-13    24.264087
# 2022-12-14    24.264087
# 2022-12-15    24.264087
# 2022-12-16    24.264087
# 2022-12-19    24.264087
# 2022-12-20    24.264087
# 2022-12-21     9.229990
# 2022-12-22     9.229990
# 2022-12-23     9.229990
# 2022-12-27     9.229990
# 2022-12-28     9.229990
# 2022-12-29    21.731938
# 2022-12-30    21.731938
# Name: slowd, dtype: float64
# KD_crs_up_pos_d_inc_until
# Time
# 2022-11-17     NaN
# 2022-11-18     NaN
# 2022-11-21     NaN
# 2022-11-22     NaN
# 2022-11-23     NaN
# 2022-11-25     NaN
# 2022-11-28     NaN
# 2022-11-29     NaN
# 2022-11-30     NaN
# 2022-12-01     NaN
# 2022-12-02     NaN
# 2022-12-05     NaN
# 2022-12-06     NaN
# 2022-12-07     NaN
# 2022-12-08     NaN
# 2022-12-09     NaN
# 2022-12-12     NaN
# 2022-12-13     NaN
# 2022-12-14     NaN
# 2022-12-15     NaN
# 2022-12-16     NaN
# 2022-12-19     NaN
# 2022-12-20     NaN
# 2022-12-21     NaN
# 2022-12-22     NaN
# 2022-12-23     NaN
# 2022-12-27     NaN
# 2022-12-28     NaN
# 2022-12-29    True
# 2022-12-30    True
# dtype: object
# KD_crs_up_pos_low_not_inc
# Time
# 2022-11-17      NaN
# 2022-11-18      NaN
# 2022-11-21      NaN
# 2022-11-22      NaN
# 2022-11-23      NaN
# 2022-11-25      NaN
# 2022-11-28      NaN
# 2022-11-29      NaN
# 2022-11-30      NaN
# 2022-12-01      NaN
# 2022-12-02      NaN
# 2022-12-05      NaN
# 2022-12-06    13.62
# 2022-12-07    13.62
# 2022-12-08    13.62
# 2022-12-09    13.62
# 2022-12-12    13.35
# 2022-12-13    13.35
# 2022-12-14    13.35
# 2022-12-15    13.35
# 2022-12-16    13.35
# 2022-12-19    13.35
# 2022-12-20    13.35
# 2022-12-21    12.32
# 2022-12-22    12.32
# 2022-12-23    12.32
# 2022-12-27    12.32
# 2022-12-28    12.32
# 2022-12-29    12.16
# 2022-12-30    12.16
# Name: low, dtype: float64
# KD_crs_up_pos_low_not_inc_until
# Time
# 2022-11-17     NaN
# 2022-11-18     NaN
# 2022-11-21     NaN
# 2022-11-22     NaN
# 2022-11-23     NaN
# 2022-11-25     NaN
# 2022-11-28     NaN
# 2022-11-29     NaN
# 2022-11-30     NaN
# 2022-12-01     NaN
# 2022-12-02     NaN
# 2022-12-05     NaN
# 2022-12-06     NaN
# 2022-12-07    True
# 2022-12-08    True
# 2022-12-09    True
# 2022-12-12    True
# 2022-12-13    True
# 2022-12-14    True
# 2022-12-15    True
# 2022-12-16    True
# 2022-12-19    True
# 2022-12-20    True
# 2022-12-21    True
# 2022-12-22    True
# 2022-12-23    True
# 2022-12-27    True
# 2022-12-28    True
# 2022-12-29    True
# 2022-12-30    True
# dtype: object
# price
#              open   high    low  close  volume
# Time
# 2022-11-17  13.81  13.99  13.66  13.90    1432
# 2022-11-18  14.43  14.54  13.86  14.01    1648
# 2022-11-21  13.99  14.24  13.78  13.82    1147
# 2022-11-22  13.64  14.00  13.34  13.95    1357
# 2022-11-23  13.95  14.40  13.86  14.38    1382
# 2022-11-25  14.35  14.67  14.33  14.48     943
# 2022-11-28  14.35  14.41  13.75  13.82    1090
# 2022-11-29  13.88  14.13  13.81  14.11    1173
# 2022-11-30  14.09  14.41  13.87  14.39    1902
# 2022-12-01  14.47  14.54  13.90  13.94    1521
# 2022-12-02  13.80  13.95  13.62  13.95    1289
# 2022-12-05  13.87  14.31  13.82  14.10    1474
# 2022-12-06  14.08  14.31  13.96  14.28    1712
# 2022-12-07  14.11  14.11  13.50  13.52    1974
# 2022-12-08  13.67  13.77  13.35  13.57    1436
# 2022-12-09  13.45  13.63  13.39  13.51    1323
# 2022-12-12  13.44  14.18  13.43  14.18    1261
# 2022-12-13  14.64  14.71  13.23  13.43    3288
# 2022-12-14  13.56  13.66  13.18  13.33    3743
# 2022-12-15  13.15  13.29  12.78  12.91    1678
# 2022-12-16  12.89  13.07  12.57  12.81    1625
# 2022-12-19  12.78  12.86  12.40  12.48    1155
# 2022-12-20  12.45  12.59  12.32  12.51    1255
# 2022-12-21  12.67  13.19  12.67  12.98    1420
# 2022-12-22  12.93  12.96  12.16  12.53    1387
# 2022-12-23  12.52  12.68  12.30  12.68    1412
# 2022-12-27  12.53  12.76  12.36  12.49    1325
# 2022-12-28  12.51  12.65  12.21  12.30    1174
# 2022-12-29  12.31  12.68  12.26  12.67    1009
# 2022-12-30  12.52  12.80  12.46  12.55     995
# KD
#                 slowk      slowd       diff  diff>0  (diff>0).diff  \
# Time
# 2022-11-17        NaN        NaN        NaN       0            NaN
# 2022-11-18        NaN        NaN        NaN       0            0.0
# 2022-11-21        NaN        NaN        NaN       0            0.0
# 2022-11-22        NaN        NaN        NaN       0            0.0
# 2022-11-23        NaN        NaN        NaN       0            0.0
# 2022-11-25        NaN        NaN        NaN       0            0.0
# 2022-11-28        NaN        NaN        NaN       0            0.0
# 2022-11-29        NaN        NaN        NaN       0            0.0
# 2022-11-30        NaN        NaN        NaN       0            0.0
# 2022-12-01        NaN        NaN        NaN       0            0.0
# 2022-12-02        NaN        NaN        NaN       0            0.0
# 2022-12-05        NaN        NaN        NaN       0            0.0
# 2022-12-06  55.288221  53.767753   1.520468       1            1.0
# 2022-12-07  40.569801  48.410485  -7.840684       0           -1.0
# 2022-12-08  27.684647  41.180889 -13.496243       0            0.0
# 2022-12-09  11.214058  26.489502 -15.275444       0            0.0
# 2022-12-12  33.893557  24.264087   9.629470       1            1.0
# 2022-12-13  32.235597  25.781071   6.454526       1            0.0
# 2022-12-14  31.021778  32.383644  -1.361866       0           -1.0
# 2022-12-15  10.017729  24.425035 -14.407306       0            0.0
# 2022-12-16   9.251542  16.763683  -7.512141       0            0.0
# 2022-12-19   7.137969   8.802413  -1.664444       0            0.0
# 2022-12-20   7.542649   7.977387  -0.434738       0            0.0
# 2022-12-21  13.009352   9.229990   3.779362       1            1.0
# 2022-12-22  16.691552  12.414518   4.277034       1            0.0
# 2022-12-23  20.839008  16.846638   3.992370       1            0.0
# 2022-12-27  18.967320  18.832627   0.134693       1            0.0
# 2022-12-28  18.260512  19.355614  -1.095101       0           -1.0
# 2022-12-29  27.967981  21.731938   6.236043       1            1.0
# 2022-12-30  33.256007  26.494834   6.761174       1            0.0
#
#             (diff>0).diff>0
# Time
# 2022-11-17            False
# 2022-11-18            False
# 2022-11-21            False
# 2022-11-22            False
# 2022-11-23            False
# 2022-11-25            False
# 2022-11-28            False
# 2022-11-29            False
# 2022-11-30            False
# 2022-12-01            False
# 2022-12-02            False
# 2022-12-05            False
# 2022-12-06             True
# 2022-12-07            False
# 2022-12-08            False
# 2022-12-09            False
# 2022-12-12             True
# 2022-12-13            False
# 2022-12-14            False
# 2022-12-15            False
# 2022-12-16            False
# 2022-12-19            False
# 2022-12-20            False
# 2022-12-21             True
# 2022-12-22            False
# 2022-12-23            False
# 2022-12-27            False
# 2022-12-28            False
# 2022-12-29             True
# 2022-12-30            False
# BB
#             upperband  middleband  lowerband
# Time
# 2022-11-17        NaN         NaN        NaN
# 2022-11-18        NaN         NaN        NaN
# 2022-11-21        NaN         NaN        NaN
# 2022-11-22        NaN         NaN        NaN
# 2022-11-23        NaN         NaN        NaN
# 2022-11-25        NaN         NaN        NaN
# 2022-11-28        NaN         NaN        NaN
# 2022-11-29        NaN         NaN        NaN
# 2022-11-30        NaN         NaN        NaN
# 2022-12-01        NaN         NaN        NaN
# 2022-12-02        NaN         NaN        NaN
# 2022-12-05        NaN         NaN        NaN
# 2022-12-06        NaN         NaN        NaN
# 2022-12-07        NaN         NaN        NaN
# 2022-12-08        NaN         NaN        NaN
# 2022-12-09        NaN         NaN        NaN
# 2022-12-12        NaN         NaN        NaN
# 2022-12-13        NaN         NaN        NaN
# 2022-12-14        NaN         NaN        NaN
# 2022-12-15        NaN         NaN        NaN
# 2022-12-16  14.762325   13.828095  12.893865
# 2022-12-19  14.870963   13.760476  12.649989
# 2022-12-20  14.924354   13.689048  12.453741
# 2022-12-21  14.922194   13.649048  12.375901
# 2022-12-22  14.939624   13.581429  12.223233
# 2022-12-23  14.861547   13.500476  12.139405
# 2022-12-27  14.756954   13.405714  12.054475
# 2022-12-28  14.755813   13.333333  11.910854
# 2022-12-29  14.667773   13.264762  11.861751
# 2022-12-30  14.509800   13.177143  11.844485
# [signal_gen_Strategy__STOCK_HIT_BBANDS_LB]
# Time
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# 2022-12-14    False
# 2022-12-15    False
# 2022-12-16     True
# 2022-12-19     True
# 2022-12-20     True
# 2022-12-21     True
# 2022-12-22     True
# 2022-12-23     True
# 2022-12-27     True
# 2022-12-28     True
# 2022-12-29     True
# 2022-12-30     True
# dtype: bool
# Time
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# 2022-12-14    False
# 2022-12-15    False
# 2022-12-16    False
# 2022-12-19    False
# 2022-12-20    False
# 2022-12-21     True
# 2022-12-22    False
# 2022-12-23    False
# 2022-12-27    False
# 2022-12-28    False
# 2022-12-29    False
# 2022-12-30    False
# dtype: bool
# Time
# 2022-11-17         NaN
# 2022-11-18         NaN
# 2022-11-21         NaN
# 2022-11-22         NaN
# 2022-11-23         NaN
# 2022-11-25         NaN
# 2022-11-28         NaN
# 2022-11-29         NaN
# 2022-11-30         NaN
# 2022-12-01         NaN
# 2022-12-02         NaN
# 2022-12-05         NaN
# 2022-12-06         NaN
# 2022-12-07         NaN
# 2022-12-08         NaN
# 2022-12-09         NaN
# 2022-12-12         NaN
# 2022-12-13         NaN
# 2022-12-14         NaN
# 2022-12-15         NaN
# 2022-12-16   -0.346665
# 2022-12-19   -0.225116
# 2022-12-20   -0.108266
# 2022-12-21    0.231002
# 2022-12-22   -0.046557
# 2022-12-23    0.117991
# 2022-12-27    0.226107
# 2022-12-28    0.210299
# 2022-12-29    0.283853
# 2022-12-30    0.461870
# dtype: float64
# Time
# 2022-11-17    False
# 2022-11-18    False
# 2022-11-21    False
# 2022-11-22    False
# 2022-11-23    False
# 2022-11-25    False
# 2022-11-28    False
# 2022-11-29    False
# 2022-11-30    False
# 2022-12-01    False
# 2022-12-02    False
# 2022-12-05    False
# 2022-12-06    False
# 2022-12-07    False
# 2022-12-08    False
# 2022-12-09    False
# 2022-12-12    False
# 2022-12-13    False
# 2022-12-14    False
# 2022-12-15    False
# 2022-12-16    False
# 2022-12-19    False
# 2022-12-20    False
# 2022-12-21    False
# 2022-12-22    False
# 2022-12-23    False
# 2022-12-27    False
# 2022-12-28    False
# 2022-12-29    False
# 2022-12-30    False
# dtype: bool
# RR_ratio =  (14.50980-12.62000)/(12.62000-12.21+0.07000) =  3.937084067761393
# KD_up_crs_D_lte20_win10 : True
# KD_crs3_win10 : False
# KD_diff_pos : True
# KD_diff3 : True
# KD_diff_inc : True
# KD_diff_inc_win2 : True
# KD_diff_lt3_win4_shift1 : False
# KD_K_slope_pos : True
# KD_D_slope_pos : True
# KD_D_slope_pos3 : True
# KD_D_slope_neg_win4_shift1 : False
# KD_D_lt20_win4_shift1 : False
# KD_D_inc6_win2 : True
# KD_K_inc6 : False
# KD_K_slope_gte5 : True
# KD_K_slope_gte10 : False
# KD_bull_divergence : True
# KD_saturate_gt6 : False
# BB_nearLB_win : True
# BB_nearLB : True
# BB_RiskReward : True
# BB_nearLB_win13 : True
# close_min : True
# close_gt_close1 : False
# close_gt_high1 : False
# close_gt_close_open_avg1 : True
# close_gt_high_low_avg1 : True
# up_candle1 : True
# up_candle : True
# now_srv_gt1500 : True
# [Strategy__STOCK_BY_BBANDS_AND_KD] Remove opend position from selected stocks ...
# [RemoveOpenPositionEver:ALL_SRC_SYMBOL] => ['#AAL']
# [RemoveOpenPositionEver:REDUCED_SYMBOL] => []
# [Strategy__STOCK_BY_BBANDS_AND_KD] open trade ...
# Tick Finished @ServerTime 2022-12-30T22:11:00+02:00
# Tick Finished @ServerTime 2022-12-30T22:11:00+02:00
# Tick Finished @ServerTime 2022-12-30T22:11:00+02:00
# Tick Finished @ServerTime 2022-12-30T22:31:00+02:00
# Tick Finished @ServerTime 2022-12-30T22:31:00+02:00
# Tick Finished @ServerTime 2022-12-30T22:31:00+02:00
# Tick Finished @ServerTime 2022-12-30T22:51:00+02:00
# Tick Finished @ServerTime 2022-12-30T22:51:00+02:00
# Tick Finished @ServerTime 2022-12-30T23:11:00+02:00
# Tick Finished @ServerTime 2022-12-30T23:11:00+02:00
# Tick Finished @ServerTime 2022-12-30T23:31:00+02:00
# Tick Finished @ServerTime 2022-12-30T23:31:00+02:00
# Tick Finished @ServerTime 2022-12-30T23:51:00+02:00
# Tick Finished @ServerTime 2022-12-30T23:51:00+02:00
# Tick Finished @ServerTime 2022-12-30T23:59:59+02:00
# Tick Finished @ServerTime 2022-12-30T23:59:59+02:00
# Tick Finished @ServerTime 2022-12-30T23:59:59+02:00

# %%
#scheduler.start(debug=True, end_date_mrk=dt.datetime.strptime('20220808','%Y%m%d'))
scheduler.start(debug=True, end_date_mrk=dt.datetime.strptime('20240308','%Y%m%d'))

# %%
scheduler.start(debug=True, end_date_mrk=dt.datetime.now(tz=tzlocal()).astimezone(pytz.timezone('America/New_York')).replace(hour=15,minute=0,second=0))

# %%
scheduler.stop()

# %%
mt.Break()
# Out:
# 'break ok'

# %% [markdown]
# ## Backtest

# %%
import datetime as dt
import pytz
from dateutil.tz import tzlocal
timestamp = mt.GetServerTime()

print(dt.datetime.fromtimestamp(timestamp))
print(dt.datetime.fromtimestamp(timestamp, tz=tzlocal()))
print(dt.datetime.fromtimestamp(timestamp, tz=pytz.utc))
print(dt.datetime.fromtimestamp(timestamp, tz=dt.timezone(dt.timedelta(hours=2))))
print(dt.datetime.utcfromtimestamp(timestamp).replace(tzinfo=dt.timezone(dt.timedelta(hours=2))).astimezone(pytz.timezone('America/New_York')))

# %%
def srv_tz_dst_compensate(src_dt):
    if src_dt.dst()==dt.timedelta(hours=0):
        return src_dt
    else:
        return src_dt-src_dt.dst()

# %%
srv_tz_dst_compensate(dt.datetime.utcfromtimestamp(timestamp).replace(tzinfo=dt.timezone(dt.timedelta(hours=2))).astimezone(pytz.timezone('America/New_York')))

# %%
import datetime as dt

dt.datetime(2024,1,1,15,0,1,22).time()
# Out:
# datetime.time(15, 0, 1, 22)

# %%
import pandas as pd
import numpy as np
s=pd.Series(range(20))
